# %% [markdown]
# # World Heritage Outlook analysis 2.0 - 2017 assessment cycle

# %% [markdown]
# ## About
#
# The 2017 cycle of assessments will not be ready until later September/October, leaving little time for analysis and for the report. This notebook is an attempt to:
#
# 1. Experiment the methodology that allows rapid analysis to be repeated with little efforts. The goal is to complete the analysis within short time, when the final data have become available
# 2. Experiment open and reproducible analysis that anyone interested could critique, repeat or improve the methodolgy if they so wish
# 3. Test ideas and scrutise the result, to uncover inconsistency and enable future iterations of outlook assessment to be more systematic and consistent
#
# ### So far
# - load CSV data (pre-processed data dumps from PostgreSQL/MS Access) into the notebook
# - utility functions to find relevant rows in the data, based on `wdpaid` and `assessment_cycle`
# - generic summary statistics (using `pandas.DataFrame.pivot_table`), for the `overall` table, notably including the `outlook` ratings. This is implemented so that any dataframe with filtered rows could be done easily, i.e., allowing subsetting by regions, countries, any attribute criteria
# - generic field-by-field change detction for the `overall` table. This is useful to identify the lowest level change (i.e. field level change for each site) but also provides a mechanism for quality control as odd changes that should not happen could be easily identified
# - generic pivot table counting for any data. I tested the functionality using `potential_threat`, in which different groups of threat categories are needed
# - viz: outlook, and its comparison
# - viz: heatmap for threats, the charts are interactive, allowing users to interrogate each cell (powered by Plot.ly)
# - finding associations between values, pm and threats to the final outlook rating
# - finding inconsistencies between individual threat listing and severity to the final threat rating
#
# ### Ideas
# - attribute filters: regions, marine, country, WH criteria, danger status. This could be easily implemented as the only change would be the input. As long as the analysis is designed in such a way that allow such input to be changed at a later stage.
# - find sites and analyse based on internal filters, such as specific threats or management

# %% [markdown]
# ## Data preparation and exploration

# %%
import os, sys
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# import plotly library for plotting

# %%
import plotly
plotly.tools.set_credentials_file(username='yichuans', api_key='DjWuYpvtG8nFh8A9U8Jb')

# ensure offline viewing of plotly graphs
# plotly.offline.init_notebook_mode(connected=True)

import plotly.plotly as py
import plotly.figure_factory as ff

from plotly.graph_objs import Bar

# %%
# !ls
# Out:
# Draft analysis.ipynb           potential_threat.csv
# WH_attributes_2017.csv         protection_management.csv
# changed_statistics.csv         temp-plot.html
# current_threat.csv             who_value_current_threat.csv
# overall.csv                    who_value_potential_threat.csv

# %% [markdown]
# Loading data into dataframes

# %%
overall = pd.read_csv('overall.csv', encoding='latin1')
current_threat = pd.read_csv('current_threat.csv', encoding='latin1')
potential_threat = pd.read_csv('potential_threat.csv', encoding='latin1')
protection_management = pd.read_csv('protection_management.csv', encoding='latin1')
value_current_threat = pd.read_csv('who_value_current_threat.csv', encoding='latin1')
value_potential_threat = pd.read_csv('who_value_potential_threat.csv', encoding='latin1')
wh_attr = pd.read_csv('WH_attributes_2017.csv')

# %%
potential_threat.columns
# Out:
# Index([u'wdpa_id', u'screenname', u'status', u'stage', u'name_en',
#        u'threat_category', u'threat_sub_category', u'potential_threat',
#        u'rating', u'inside_site', u'outside_site', u'assessment_cycle'],
#       dtype='object')

# %%
value_current_threat.columns
# Out:
# Index([u'wdpa_id', u'assessment_version_id', u'screenname', u'status',
#        u'stage', u'name_en', u'values_', u'criterion', u'current_threat',
#        u'threat_category', u'threat_sub_category', u'assessment_cycle'],
#       dtype='object')

# %%
overall.columns
# Out:
# Index([u'wdpa_id', u'screenname', u'status', u'stage', u'name_en', u'outlook',
#        u'overall_threat', u'current_threat', u'potential_threat', u'prot_mgmt',
#        u'wh_value', u'wh_trend', u'biodiv_value', u'biodiv_trend', u'language',
#        u'assessment_cycle'],
#       dtype='object')

# %%
current_threat.columns
# Out:
# Index([u'wdpa_id', u'screenname', u'status', u'stage', u'name_en',
#        u'threat_category', u'threat_sub_category', u'rating', u'inside_site',
#        u'outside_site', u'assessment_version_id', u'assessment_cycle'],
#       dtype='object')

# %%
current_threat.dtypes
# Out:
# wdpa_id                    int64
# screenname                object
# status                    object
# stage                     object
# name_en                   object
# threat_category           object
# threat_sub_category       object
# rating                    object
# inside_site              float64
# outside_site             float64
# assessment_version_id      int64
# assessment_cycle           int64
# dtype: object

# %%
overall.dtypes
# Out:
# wdpa_id              int64
# screenname          object
# status              object
# stage               object
# name_en             object
# outlook             object
# overall_threat      object
# current_threat      object
# potential_threat    object
# prot_mgmt           object
# wh_value            object
# wh_trend            object
# biodiv_value        object
# biodiv_trend        object
# language             int64
# assessment_cycle     int64
# dtype: object

# %%
overall.index.size, overall.wdpa_id.nunique()
# Out:
# (385, 235)

# %%
protection_management[pd.isnull(protection_management.pm_rating)]
# Out:
#         wdpa_id       screenname       status       stage  \
# 3052      10902           tilman    Completed  Assessment
# 3229      61609            elena    Completed  Assessment
# 3243  555556048            elena    Completed  Assessment
# 3262      12896     steffenoppel    Completed  Assessment
# 3277  555577555             alan    Completed  Assessment
# 3292       2006        hanshurni    Completed  Assessment
# 3302     903138            tarek    Completed  Assessment
# 3329     902487            tarek    Completed  Assessment
# 3334       4999            tarek    Completed  Assessment
# 3351  555542337            tarek    Completed  Assessment
# 3372      93767         alexbond    Completed  Assessment
# 3397     902479            wendy    Completed  Assessment
# 3416     902347        guypalmer    Completed  Assessment
# 3429     198291           tilman  In Progress  Assessment
# 3437      61608   robertbitariho    Completed  Assessment
# 3446  555512006   vincentboullet  In Progress  Assessment
# 3448     145580            naomi    Completed  Assessment
# 3467     145586       elejansaaf    Completed  Assessment
# 3481     903134  catherinegabrie    Completed  Assessment
# 3509      10907      vernonbooth    Completed  Assessment
# 3510      10907      vernonbooth    Completed  Assessment
# 3525      20399      vernonbooth    Completed  Assessment
# 3526      20399      vernonbooth    Completed  Assessment
# 3533      61611            wendy    Completed  Assessment
# 3543     198303        mallarach  In Progress  Assessment
# 3558      67728           tobias  In Progress  Assessment
# 3559      67728           tobias  In Progress  Assessment
# 3574       4326           tobias  In Progress  Assessment
# 3575       4326           tobias  In Progress  Assessment
# 3587       9613           tobias  In Progress  Assessment
# ...         ...              ...          ...         ...
# 5283     900008            elena  In Progress  Assessment
# 5285      10745            elena  In Progress  Assessment
# 5286      10745            elena  In Progress  Assessment
# 5304     124389            elena  In Progress  Assessment
# 5305     124389            elena  In Progress  Assessment
# 5331       2554           tilman  In Progress  Assessment
# 5335       5001            elena  In Progress  Assessment
# 5336       5001            elena  In Progress  Assessment
# 5362       2570           tilman  In Progress  Assessment
# 5378     220291           tilman  In Progress  Assessment
# 5394       5000           tilman  In Progress  Assessment
# 5410     900881           tilman  In Progress  Assessment
# 5426        197           tilman  In Progress  Assessment
# 5430      61610           tilman  In Progress  Assessment
# 5458      17760           tilman  In Progress  Assessment
# 5467     220297           tilman  In Progress  Assessment
# 5490     902482           tilman  In Progress  Assessment
# 5506       2577           destry  In Progress  Assessment
# 5507       2577           destry  In Progress  Assessment
# 5522       2579           destry  In Progress  Assessment
# 5523       2579           destry  In Progress  Assessment
# 5528  555556047            elena  In Progress  Assessment
# 5529  555556047            elena  In Progress  Assessment
# 5554     903140            elena  In Progress  Assessment
# 5555     903140            elena  In Progress  Assessment
# 5557      93292            juraj  In Progress  Assessment
# 5577       2005       chuckblyth    Completed  Assessment
# 5599      93291           destry    Completed  Assessment
# 5618       4327            elena  In Progress  Assessment
# 5619       4327            elena  In Progress  Assessment
#
#                                                 name_en  \
# 3052                         Wood Buffalo National Park
# 3229                  Bwindi Impenetrable National Park
# 3243                                     Namib Sand Sea
# 3262                                   Henderson Island
# 3277                                     Okavango Delta
# 3292                               Simien National Park
# 3302                                Socotra Archipelago
# 3329                       Wadi Al-Hitan (Whale Valley)
# 3334                      Tassili n'Ajjer National Park
# 3351                            Wadi Rum Protected Area
# 3372                     Gough and Inaccessible Islands
# 3397  Coiba National Park and its Special Zone of Ma...
# 3416                 Cape Floral Region Protected Areas
# 3429                                   Península Valdés
# 3437                   Rwenzori Mountains National Park
# 3446     Pitons, cirques and remparts of Reunion Island
# 3448                                     The Sundarbans
# 3467                        Lake Turkana National Parks
# 3481  Lagoons of New Caledonia: Reef Diversity and A...
# 3509  Mana Pools National Park, Sapi and Chewore Saf...
# 3510  Mana Pools National Park, Sapi and Chewore Saf...
# 3525                     Mosi-oa-Tunya / Victoria Falls
# 3526                     Mosi-oa-Tunya / Victoria Falls
# 3533                               Doñana National Park
# 3543                    Ibiza: Biodiversity and Culture
# 3558                                       Danube Delta
# 3559                                       Danube Delta
# 3574                             Durmitor National Park
# 3575                             Durmitor National Park
# 3587                                Pirin National Park
# ...                                                 ...
# 5283                      Isole Eolie (Aeolian Islands)
# 5285                           Manas Wildlife Sanctuary
# 5286                           Manas Wildlife Sanctuary
# 5304                             Okapi Wildlife Reserve
# 5305                             Okapi Wildlife Reserve
# 5331                               Darién National Park
# 5335                             Lord Howe Island Group
# 5336                             Lord Howe Island Group
# 5362                        Los Glaciares National Park
# 5378              Ischigualasto-Talampaya Natural Parks
# 5394                               Tasmanian Wilderness
# 5410    Three Parallel Rivers of Yunnan Protected Areas
# 5426                                Tikal National Park
# 5430                           Los Katios National Park
# 5458                                 Manú National Park
# 5467                      Pantanal Conservation Complex
# 5490                                          Shiretoko
# 5506                         Mammoth Cave National Park
# 5507                         Mammoth Cave National Park
# 5522                              Olympic National Park
# 5523                              Olympic National Park
# 5528                                         Mount Etna
# 5529                                         Mount Etna
# 5554                       Swiss Tectonic Arena Sardona
# 5555                       Swiss Tectonic Arena Sardona
# 5557           Caves of Aggtelek Karst and Slovak Karst
# 5577                              Nahanni National Park
# 5599                     Carlsbad Caverns National Park
# 5618                              Garamba National Park
# 5619                              Garamba National Park
#
#                                                   topic pm_rating  \
# 3052  Assessment of the effectiveness of protection ...       NaN
# 3229  Assessment of the effectiveness of protection ...       NaN
# 3243  Assessment of the effectiveness of protection ...       NaN
# 3262  Assessment of the effectiveness of protection ...       NaN
# 3277  Assessment of the effectiveness of protection ...       NaN
# 3292  Assessment of the effectiveness of protection ...       NaN
# 3302  Assessment of the effectiveness of protection ...       NaN
# 3329  Assessment of the effectiveness of protection ...       NaN
# 3334  Assessment of the effectiveness of protection ...       NaN
# 3351  Assessment of the effectiveness of protection ...       NaN
# 3372  Assessment of the effectiveness of protection ...       NaN
# 3397  Assessment of the effectiveness of protection ...       NaN
# 3416  Assessment of the effectiveness of protection ...       NaN
# 3429                                                NaN       NaN
# 3437  Assessment of the effectiveness of protection ...       NaN
# 3446                                                NaN       NaN
# 3448  Assessment of the effectiveness of protection ...       NaN
# 3467  Assessment of the effectiveness of protection ...       NaN
# 3481  Assessment of the effectiveness of protection ...       NaN
# 3509  Assessment of the effectiveness of protection ...       NaN
# 3510                                        Enforcement       NaN
# 3525  Assessment of the effectiveness of protection ...       NaN
# 3526                                        Enforcement       NaN
# 3533  Assessment of the effectiveness of protection ...       NaN
# 3543                                                NaN       NaN
# 3558  Assessment of the effectiveness of protection ...       NaN
# 3559                                        Enforcement       NaN
# 3574  Assessment of the effectiveness of protection ...       NaN
# 3575                                        Enforcement       NaN
# 3587                                        Enforcement       NaN
# ...                                                 ...       ...
# 5283                                        Enforcement       NaN
# 5285  Assessment of the effectiveness of protection ...       NaN
# 5286                                        Enforcement       NaN
# 5304  Assessment of the effectiveness of protection ...       NaN
# 5305                                        Enforcement       NaN
# 5331  Assessment of the effectiveness of protection ...       NaN
# 5335  Assessment of the effectiveness of protection ...       NaN
# 5336                                        Enforcement       NaN
# 5362  Assessment of the effectiveness of protection ...       NaN
# 5378  Assessment of the effectiveness of protection ...       NaN
# 5394  Assessment of the effectiveness of protection ...       NaN
# 5410  Assessment of the effectiveness of protection ...       NaN
# 5426  Assessment of the effectiveness of protection ...       NaN
# 5430  Assessment of the effectiveness of protection ...       NaN
# 5458  Assessment of the effectiveness of protection ...       NaN
# 5467  Assessment of the effectiveness of protection ...       NaN
# 5490  Assessment of the effectiveness of protection ...       NaN
# 5506  Assessment of the effectiveness of protection ...       NaN
# 5507                                        Enforcement       NaN
# 5522  Assessment of the effectiveness of protection ...       NaN
# 5523                                        Enforcement       NaN
# 5528  Assessment of the effectiveness of protection ...       NaN
# 5529                                        Enforcement       NaN
# 5554  Assessment of the effectiveness of protection ...       NaN
# 5555                                        Enforcement       NaN
# 5557  Assessment of the effectiveness of protection ...       NaN
# 5577  Assessment of the effectiveness of protection ...       NaN
# 5599  Assessment of the effectiveness of protection ...       NaN
# 5618  Assessment of the effectiveness of protection ...       NaN
# 5619                                        Enforcement       NaN
#
#       assessment_cycle
# 3052              2017
# 3229              2017
# 3243              2017
# 3262              2017
# 3277              2017
# 3292              2017
# 3302              2017
# 3329              2017
# 3334              2017
# 3351              2017
# 3372              2017
# 3397              2017
# 3416              2017
# 3429              2017
# 3437              2017
# 3446              2017
# 3448              2017
# 3467              2017
# 3481              2017
# 3509              2017
# 3510              2017
# 3525              2017
# 3526              2017
# 3533              2017
# 3543              2017
# 3558              2017
# 3559              2017
# 3574              2017
# 3575              2017
# 3587              2017
# ...                ...
# 5283              2017
# 5285              2017
# 5286              2017
# 5304              2017
# 5305              2017
# 5331              2017
# 5335              2017
# 5336              2017
# 5362              2017
# 5378              2017
# 5394              2017
# 5410              2017
# 5426              2017
# 5430              2017
# 5458              2017
# 5467              2017
# 5490              2017
# 5506              2017
# 5507              2017
# 5522              2017
# 5523              2017
# 5528              2017
# 5529              2017
# 5554              2017
# 5555              2017
# 5557              2017
# 5577              2017
# 5599              2017
# 5618              2017
# 5619              2017
#
# [231 rows x 8 columns]

# %%
protection_management.head()
# Out:
#    wdpa_id screenname     status      stage                       name_en  \
# 0     2010      elena  Completed  Published  Ngorongoro Conservation Area
# 1     2010      elena  Completed  Published  Ngorongoro Conservation Area
# 2     2010      elena  Completed  Published  Ngorongoro Conservation Area
# 3     2010      elena  Completed  Published  Ngorongoro Conservation Area
# 4     2010      elena  Completed  Published  Ngorongoro Conservation Area
#
#                                                topic         pm_rating  \
# 0  Relationships with local people (including sta...         Effective
# 1                                    Legal framework         Effective
# 2  Integration into regional and national plannin...         Effective
# 3  Management system (for transboundary/serial pr...  Highly Effective
# 4                           Management effectiveness         Effective
#
#    assessment_cycle
# 0              2014
# 1              2014
# 2              2014
# 3              2014
# 4              2014

# %%
value_current_threat.head()
# Out:
#    wdpa_id  assessment_version_id screenname     status      stage  \
# 0    26653                   4302      elena  Completed  Published
# 1    26653                   4302      elena  Completed  Published
# 2    26653                   4302      elena  Completed  Published
# 3    26653                   4302      elena  Completed  Published
# 4    26653                   4302      elena  Completed  Published
#
#                                     name_en  \
# 0  Tsingy de Bemaraha Strict Nature Reserve
# 1  Tsingy de Bemaraha Strict Nature Reserve
# 2  Tsingy de Bemaraha Strict Nature Reserve
# 3  Tsingy de Bemaraha Strict Nature Reserve
# 4  Tsingy de Bemaraha Strict Nature Reserve
#
#                                             values_  criterion  \
# 0  Unique and spectacular geomorphological features          7
# 1  Unique and spectacular geomorphological features          7
# 2  Unique and spectacular geomorphological features          7
# 3  Unique and spectacular geomorphological features          7
# 4  Unique and spectacular geomorphological features          7
#
#                  current_threat  \
# 0        Extreme weather events
# 1        Alien Invasive Species
# 2  Marine pollution and garbage
# 3        Alien Invasive Species
# 4        Alien Invasive Species
#
#                                     threat_category  \
# 0                 Climate Change and Severe Weather
# 1  Invasive and Other Problematic Species and Genes
# 2                                         Pollution
# 3  Invasive and Other Problematic Species and Genes
# 4  Invasive and Other Problematic Species and Genes
#
#                   threat_sub_category  assessment_cycle
# 0                     Storms/Flooding              2014
# 1  Invasive Non-Native/ Alien Species              2014
# 2                     Water Pollution              2014
# 3  Invasive Non-Native/ Alien Species              2014
# 4  Invasive Non-Native/ Alien Species              2014

# %%
value_potential_threat.head()
# Out:
#    wdpa_id  assessment_version_id screenname     status      stage  \
# 0    26653                   4302      elena  Completed  Published
# 1    26653                   4302      elena  Completed  Published
# 2    26653                   4302      elena  Completed  Published
# 3    26653                   4302      elena  Completed  Published
# 4    26653                   4302      elena  Completed  Published
#
#                                     name_en  \
# 0  Tsingy de Bemaraha Strict Nature Reserve
# 1  Tsingy de Bemaraha Strict Nature Reserve
# 2  Tsingy de Bemaraha Strict Nature Reserve
# 3  Tsingy de Bemaraha Strict Nature Reserve
# 4  Tsingy de Bemaraha Strict Nature Reserve
#
#                                             values_  criterion  \
# 0  Unique and spectacular geomorphological features          7
# 1  Unique and spectacular geomorphological features          7
# 2  Unique and spectacular geomorphological features          7
# 3  Unique and spectacular geomorphological features          7
# 4  Unique and spectacular geomorphological features          7
#
#   potential_threat                    threat_category   threat_sub_category  \
# 0   Climate change  Climate Change and Severe Weather  Temperature extremes
# 1   Climate change  Climate Change and Severe Weather   Ocean acidification
# 2   Climate change  Climate Change and Severe Weather  Temperature extremes
# 3   Climate change  Climate Change and Severe Weather   Ocean acidification
# 4   Climate change  Climate Change and Severe Weather   Ocean acidification
#
#    assessment_cycle
# 0              2014
# 1              2014
# 2              2014
# 3              2014
# 4              2014

# %% [markdown]
# ## Overall conservation outlook
#
# Filters for 2014 and 2017 cycles of assessment

# %%
CYCLE_2017_OVERALL = overall.assessment_cycle == 2017
CYCLE_2014_OVERALL = overall.assessment_cycle == 2014

# %%
overall.head()
# Out:
#    wdpa_id screenname     status      stage  \
# 0   124388      elena  Completed  Published
# 1    26653      elena  Completed  Published
# 2    20171      elena  Completed  Published
# 3    61608       alok  Completed  Published
# 4   902347      elena  Completed  Published
#
#                                     name_en                  outlook  \
# 0                             Laponian Area                     Good
# 1  Tsingy de Bemaraha Strict Nature Reserve                     Good
# 2  Cliff of Bandiagara (Land of the Dogons)      Significant Concern
# 3          Rwenzori Mountains National Park  Good with some concerns
# 4        Cape Floral Region Protected Areas  Good with some concerns
#
#     overall_threat   current_threat potential_threat         prot_mgmt  \
# 0  Very Low Threat  Very Low Threat       Low Threat  Highly Effective
# 1       Low Threat       Low Threat   Data Deficient         Effective
# 2      High Threat      High Threat              NaN   Serious Concern
# 3       Low Threat       Low Threat   Data Deficient         Effective
# 4      High Threat      High Threat      High Threat         Effective
#
#        wh_value        wh_trend    biodiv_value    biodiv_trend  language  \
# 0          Good          Stable             NaN             NaN         1
# 1   Low Concern          Stable             NaN             NaN         1
# 2  High Concern   Deteriorating  Data Deficient  Data Deficient         2
# 3   Low Concern  Data Deficient  Data Deficient  Data Deficient         1
# 4   Low Concern          Stable             NaN             NaN         1
#
#    assessment_cycle
# 0              2014
# 1              2014
# 2              2014
# 3              2014
# 4              2014

# %% [markdown]
# The number of unique records for 2014 and 2017 cycles

# %%
overall[CYCLE_2014_OVERALL].wdpa_id.nunique(), overall[CYCLE_2017_OVERALL].wdpa_id.nunique()
# Out:
# (229, 156)

# %% [markdown]
# Quality checks on the data: what are the sites that are in 2014 but not in 2017 and vice versa? Or what is the number of sites that have two assessments?

# %%
wdpaid_shared_between_cycles = overall[CYCLE_2014_OVERALL].wdpa_id.isin(overall[CYCLE_2017_OVERALL].wdpa_id.values)
print('Total number of shared sites between two cycles: {}'.format(wdpaid_shared_between_cycles.sum()))
# Out:
# Total number of shared sites between two cycles: 150

# %% [markdown]
# ### Overall outlook statistics

# %%
overall[CYCLE_2014_OVERALL].pivot_table(values='wdpa_id', columns='outlook', aggfunc=np.count_nonzero)
# Out:
# outlook  Critical  Good  Good with some concerns  Significant Concern
# wdpa_id        19    47                       96                   67

# %%
## create a more generic version of get number statistics
def summary_statistics(df, columns, aggfunc=np.count_nonzero):
    result = df.pivot_table(values='wdpa_id', columns=columns, aggfunc=aggfunc)
    result.index = [' '] # remove wdpa_id as index value
    return result

# %%
pd.DataFrame.pivot_table(overall, columns='outlook', values='wdpa_id', aggfunc=np.count_nonzero)
# Out:
# outlook  Critical  Good  Good with some concerns  Significant Concern
# wdpa_id        32    68                      164                  116

# %%
pd.DataFrame.pivot_table(overall, index='outlook', values='wdpa_id', aggfunc=np.count_nonzero)
# Out:
#                          wdpa_id
# outlook
# Critical                      32
# Good                          68
# Good with some concerns      164
# Significant Concern          116

# %%
summary_statistics(overall, columns=['outlook'])
# Out:
# outlook  Critical  Good  Good with some concerns  Significant Concern
#                32    68                      164                  116

# %%
overall[CYCLE_2014_OVERALL].columns
# Out:
# Index([u'wdpa_id', u'screenname', u'status', u'stage', u'name_en', u'outlook',
#        u'overall_threat', u'current_threat', u'potential_threat', u'prot_mgmt',
#        u'wh_value', u'wh_trend', u'biodiv_value', u'biodiv_trend', u'language',
#        u'assessment_cycle'],
#       dtype='object')

# %%
summary_statistics(overall[CYCLE_2014_OVERALL], 'outlook')
# Out:
# outlook  Critical  Good  Good with some concerns  Significant Concern
#                19    47                       96                   67

# %%
a = summary_statistics(overall[CYCLE_2014_OVERALL], 'current_threat')

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
cols = [u'status', u'stage', u'outlook', u'overall_threat', u'current_threat', u'potential_threat', u'prot_mgmt', u'wh_value', u'wh_trend', u'biodiv_value', u'biodiv_trend', u'language']
for col in cols:
    print summary_statistics(overall[CYCLE_2014_OVERALL], col)
# Out:
# status  Completed  In Progress
#               228            1
# stage  Approved  Assessment  Published  Translated
#               1           1        224           3
# outlook  Critical  Good  Good with some concerns  Significant Concern
#                19    47                       96                   67
# overall_threat  High Threat  Low Threat  Very High Threat  Very Low Threat
#                          90          88                33               18
# current_threat  High Threat  Low Threat  Very High Threat  Very Low Threat
#                          89          91                30               19
# potential_threat  Data Deficient  High Threat  Low Threat  Very High Threat  \
#                               26           84          71                24
#
# potential_threat  Very Low Threat
#                                15
# prot_mgmt  Effective  Highly Effective  Serious Concern  Some Concern
#                  103                23               29            74
# wh_value  Critical  Good  High Concern  Low Concern
#                 10    57            58          104
# wh_trend  Data Deficient  Deteriorating  Improving  Stable
#                       44             59         12     114
# biodiv_value  Critical  Data Deficient  Good  High Concern  Low Concern
#                      2              27    12            33           38
# biodiv_trend  Data Deficient  Deteriorating  Improving  Stable
#                           58             22          4      28
# language    1   2  3
#           213  12  4

# %%
cols = [u'status', u'stage', u'outlook', u'overall_threat', u'current_threat', u'potential_threat', u'prot_mgmt', u'wh_value', u'wh_trend', u'biodiv_value', u'biodiv_trend', u'language']
for col in cols:
    print summary_statistics(overall[CYCLE_2017_OVERALL], col)
# Out:
# status  Completed  In Progress
#                48          108
# stage  Assessment
#               156
# outlook  Critical  Good  Good with some concerns  Significant Concern
#                13    21                       68                   49
# overall_threat  Data Deficient  High Threat  Low Threat  Very High Threat  \
#                              1           67          51                22
#
# overall_threat  Very Low Threat
#                              10
# current_threat  Data Deficient  High Threat  Low Threat  Very High Threat  \
#                              1           64          54                22
#
# current_threat  Very Low Threat
#                              10
# potential_threat  Data Deficient  High Threat  Low Threat  Very High Threat  \
#                               14           59          47                17
#
# potential_threat  Very Low Threat
#                                 8
# prot_mgmt  Effective  Highly Effective  Serious Concern  Some Concern
#                   57                11               20            62
# wh_value  Critical  Good  High Concern  Low Concern
#                  7    38            44           62
# wh_trend  Data Deficient  Deteriorating  Improving  Stable
#                       23             47          9      72
# biodiv_value  Critical  Data Deficient  Good  High Concern  Low Concern
#                      1              18    10            26           23
# biodiv_trend  Data Deficient  Deteriorating  Improving  Stable
#                           34             21          7      16
# language    1   2  3
#           142  11  3

# %% [markdown]
# By adding further filters, such as regions/countries/(other attributes), in the form of list of wdpaids, it can calculate statistics reusing the `summary_statistics` function. TBD: apply wdpaid filter, perhaps `isin`

# %% [markdown]
# ### Overall outlook viz
# Investigate visualisation options

# %%
print(plt.style.available)
# Out:
# [u'seaborn-darkgrid', u'seaborn-notebook', u'classic', u'seaborn-ticks', u'grayscale', u'bmh', u'seaborn-talk', u'dark_background', u'ggplot', u'fivethirtyeight', u'seaborn-colorblind', u'seaborn-deep', u'seaborn-whitegrid', u'seaborn-bright', u'seaborn-poster', u'seaborn-muted', u'seaborn-paper', u'seaborn-white', u'seaborn-pastel', u'seaborn-dark', u'seaborn-dark-palette']

# %%
plt.style.use('ggplot')

# %%
summary_statistics(overall[CYCLE_2014_OVERALL], 'outlook').plot.barh(stacked=True)

# %%
def plot_outlook(df):
    # use WHO colour scheme
    red, orange, green, deep_green, grey =('#E22626','#F69220', '#ACCD73', '#49AA4A', '#A0A0A0')
    fig, axes = plt.subplots(1, figsize=(20, 2))
    
    my_colors = [deep_green, green, orange, red]
    my_labels = ['Good', 'Good with some concerns', 'Significant Concern', 'Critical']
    data = df[my_labels]

    c = data.plot.barh(ax=axes, stacked=True, color=my_colors)
    axes.set_xlim([0, data.values.sum()])
    axes.legend_.remove()
    
    # ensure all 1-d array to zip, thus flatten
    for value, value_cum, label in zip(data.values.flatten(), data.values.cumsum(), my_labels):
        axes.annotate(label + ' ({})'.format(value), (value_cum - value/2.0, 0),
                      horizontalalignment='center', verticalalignment='center')
    
    return fig

# %%
## a genric plot function, requiring the scheme to be sorted before hand
def plot_summary_statistics(df):
    # use WHO colour scheme
    red, orange, green, deep_green, grey =('#E22626','#F69220', '#ACCD73', '#49AA4A', '#A0A0A0')
    fig, axes = plt.subplots(1, figsize=(20, 2))
    
    my_colors = [deep_green, green, orange, red, grey]
    my_labels = df.columns
    data = df

    c = data.plot.barh(ax=axes, stacked=True, color=my_colors)
    axes.set_xlim([0, data.values.sum()])
    axes.legend_.remove()
    
    # ensure all 1-d array to zip, thus flatten
    for value, value_cum, label in zip(data.values.flatten(), data.values.cumsum(), my_labels):
        axes.annotate(label + ' ({})'.format(value), (value_cum - value/2.0, 0),
                      horizontalalignment='center', verticalalignment='center')
    
    return fig

# %% [markdown]
# **overall outlook 2014 - 2017**

# %%
plot_outlook(summary_statistics(overall[CYCLE_2014_OVERALL], 'outlook'))

# %%
plot_outlook(summary_statistics(overall[CYCLE_2017_OVERALL], 'outlook'))

# %% [markdown]
# Testing generic statistics ploting function, noting the need to re-order columns

# %% [markdown]
# **potential threat 2014 - 2017**

# %%
plot_summary_statistics(summary_statistics(overall[CYCLE_2014_OVERALL], 'potential_threat')[['Very Low Threat','Low Threat','High Threat','Very High Threat', 'Data Deficient']])

# %%
plot_summary_statistics(summary_statistics(overall[CYCLE_2017_OVERALL], 'potential_threat')[['Very Low Threat','Low Threat','High Threat','Very High Threat', 'Data Deficient']])

# %% [markdown]
# **current threat 2014 - 2017**

# %%
plot_summary_statistics(summary_statistics(overall[CYCLE_2014_OVERALL], 'current_threat')[['Very Low Threat','Low Threat','High Threat','Very High Threat']])

# %%
plot_summary_statistics(summary_statistics(overall[CYCLE_2017_OVERALL], 'current_threat')[['Very Low Threat','Low Threat','High Threat','Very High Threat', 'Data Deficient']])

# %% [markdown]
# ### Detect change from 2014 and 2017
#
# It would be desirable during analysis to understand what change may have happened for each site (if any)

# %%
b = overall[overall.wdpa_id == 191]

# %%
b
# Out:
#      wdpa_id screenname       status       stage            name_en  \
# 177      191      elena    Completed   Published  Galápagos Islands
# 258      191      wendy  In Progress  Assessment  Galápagos Islands
#
#                  outlook    overall_threat    current_threat  \
# 177  Significant Concern  Very High Threat  Very High Threat
# 258  Significant Concern  Very High Threat  Very High Threat
#
#      potential_threat  prot_mgmt      wh_value       wh_trend  biodiv_value  \
# 177  Very High Threat  Effective  High Concern  Deteriorating  High Concern
# 258  Very High Threat  Effective  High Concern  Deteriorating  High Concern
#
#       biodiv_trend  language  assessment_cycle
# 177  Deteriorating         1              2014
# 258  Deteriorating         1              2017

# %%
def bb(df):
    ## 0 indicate different values in the series
    if df.screenname.duplicated(False).sum() == 0:
        return df.outlook
    ## either same value or one value only (only one cycle of assessment)
    else:
        return pd.Series(['-'])
    
# def apply_comparison(df):
#     df[field]

# %%
for key, group in b.groupby('wdpa_id'):
    print key, group
# Out:
# 191      wdpa_id screenname       status       stage            name_en  \
# 177      191      elena    Completed   Published  Galápagos Islands
# 258      191      wendy  In Progress  Assessment  Galápagos Islands
#
#                  outlook    overall_threat    current_threat  \
# 177  Significant Concern  Very High Threat  Very High Threat
# 258  Significant Concern  Very High Threat  Very High Threat
#
#      potential_threat  prot_mgmt      wh_value       wh_trend  biodiv_value  \
# 177  Very High Threat  Effective  High Concern  Deteriorating  High Concern
# 258  Very High Threat  Effective  High Concern  Deteriorating  High Concern
#
#       biodiv_trend  language  assessment_cycle
# 177  Deteriorating         1              2014
# 258  Deteriorating         1              2017

# %%
b.groupby('wdpa_id').apply(bb)
# Out:
# outlook                  177                  258
# wdpa_id
# 191      Significant Concern  Significant Concern

# %% [markdown]
# try a different way to detect changes

# %%
wdpaid_shared_between_cycles = overall[CYCLE_2014_OVERALL].wdpa_id.isin(overall[CYCLE_2017_OVERALL].wdpa_id.values)

# %%
common_wdpaids = overall[CYCLE_2014_OVERALL].wdpa_id[wdpaid_shared_between_cycles]

# %%
overall.columns.tolist()
# Out:
# [u'wdpa_id',
#  u'screenname',
#  u'status',
#  u'stage',
#  u'name_en',
#  u'outlook',
#  u'overall_threat',
#  u'current_threat',
#  u'potential_threat',
#  u'prot_mgmt',
#  u'wh_value',
#  u'wh_trend',
#  u'biodiv_value',
#  u'biodiv_trend',
#  u'language',
#  u'assessment_cycle']

# %% [markdown]
# Only the WDPAID is the unique identifier re rows, but en_name is useful for checks

# %%
def detect_change_col(wdpaid, df, col):
    """"one row per cycle, i.e. one to one relationship"""
    # brutal force not efficient, first row
    value_2017 = df[(df.assessment_cycle==2017) & (df.wdpa_id==wdpaid)][col].iloc[0]
    value_2014 = df[(df.assessment_cycle==2014) & (df.wdpa_id==wdpaid)][col].iloc[0]
    
    if value_2017 == value_2014:
        return None
    
    # if both variables are of type float and nan, don't do anything
    elif isinstance(value_2017, float) and isinstance(value_2014, float):
        if math.isnan(value_2017) and math.isnan(value_2014):
            return None
        
    # detected change, record
    else:
        return ' -> '.join(map(str, [value_2014, value_2017]))

def detect_change_df(df):
    output = list()
    
    # go through all fields and remove unnecesary fields
    excluded_cols = ['wdpa_id', 'screenname', 'status', 'stage', 'assessment_cycle']
    cols = df.columns.tolist()

    for excluded_col in excluded_cols:
        if excluded_col in cols:
            cols.remove(excluded_col)
    
    # for each site do detection check
    for wdpaid in common_wdpaids:
        for col in cols:
            result = detect_change_col(wdpaid, df, col)
            # if detected
            if result:
                output.append([wdpaid, col, result])
    
    # append en_name 
    output_df = pd.DataFrame(data=output, columns=['wdpaid', 'column', 'value'])
    output_full = pd.merge(output_df, wh_attr, how='inner', on='wdpaid')[['wdpaid', 'en_name', 'column', 'value']]
    
    return output_full

# %%
changed_stats = detect_change_df(overall)

# %%
changed_stats.to_csv('changed_statistics.csv', encoding='utf-8')

# %%
changed_stats.dtypes
# Out:
# wdpaid      int64
# en_name    object
# column     object
# value      object
# dtype: object

# %%
changed_stats
# Out:
#      wdpaid                                   en_name            column  \
# 0     26653  Tsingy de Bemaraha Strict Nature Reserve           outlook
# 1     26653  Tsingy de Bemaraha Strict Nature Reserve    overall_threat
# 2     26653  Tsingy de Bemaraha Strict Nature Reserve    current_threat
# 3     26653  Tsingy de Bemaraha Strict Nature Reserve  potential_threat
# 4     26653  Tsingy de Bemaraha Strict Nature Reserve         prot_mgmt
# 5     26653  Tsingy de Bemaraha Strict Nature Reserve          wh_value
# 6     26653  Tsingy de Bemaraha Strict Nature Reserve      biodiv_value
# 7     26653  Tsingy de Bemaraha Strict Nature Reserve      biodiv_trend
# 8     26653  Tsingy de Bemaraha Strict Nature Reserve          language
# 9     61608          Rwenzori Mountains National Park         prot_mgmt
# 10   902347        Cape Floral Region Protected Areas           outlook
# 11   902347        Cape Floral Region Protected Areas         prot_mgmt
# 12   902347        Cape Floral Region Protected Areas          wh_value
# 13   902347        Cape Floral Region Protected Areas          wh_trend
# 14    17761                 Kilimanjaro National Park      biodiv_value
# 15    17761                 Kilimanjaro National Park      biodiv_trend
# 16     4999                           Tassili n'Ajjer    overall_threat
# 17     4999                           Tassili n'Ajjer    current_threat
# 18     4999                           Tassili n'Ajjer          wh_value
# 19     2010              Ngorongoro Conservation Area      biodiv_value
# 20     2010              Ngorongoro Conservation Area      biodiv_trend
# 21   902487              Wadi Al-Hitan (Whale Valley)           outlook
# 22    67727           Aïr and Ténéré Natural Reserves  potential_threat
# 23    67727           Aïr and Ténéré Natural Reserves         prot_mgmt
# 24    67727           Aïr and Ténéré Natural Reserves          language
# 25     4322                     Ichkeul National Park          language
# 26   168242                              East Rennell           outlook
# 27   168242                              East Rennell          wh_trend
# 28   903130       Jeju Volcanic Island and Lava Tubes  potential_threat
# 29   903130       Jeju Volcanic Island and Lava Tubes      biodiv_value
# ..      ...                                       ...               ...
# 98     9623        Historic Sanctuary of Machu Picchu    current_threat
# 99     9623        Historic Sanctuary of Machu Picchu  potential_threat
# 100    9623        Historic Sanctuary of Machu Picchu         prot_mgmt
# 101    9623        Historic Sanctuary of Machu Picchu          wh_value
# 102    9623        Historic Sanctuary of Machu Picchu          wh_trend
# 103    9623        Historic Sanctuary of Machu Picchu      biodiv_value
# 104    9623        Historic Sanctuary of Machu Picchu      biodiv_trend
# 105    2004                  Dinosaur Provincial Park  potential_threat
# 106    2004                  Dinosaur Provincial Park          wh_value
# 107    2004                  Dinosaur Provincial Park      biodiv_value
# 108   12896                          Henderson Island         prot_mgmt
# 109    2013                 Yellowstone National Park  potential_threat
# 110    2013                 Yellowstone National Park      biodiv_value
# 111    2013                 Yellowstone National Park      biodiv_trend
# 112   10902                Wood Buffalo National Park           outlook
# 113   10902                Wood Buffalo National Park    overall_threat
# 114   10902                Wood Buffalo National Park  potential_threat
# 115   10902                Wood Buffalo National Park         prot_mgmt
# 116   10902                Wood Buffalo National Park          wh_value
# 117   10902                Wood Buffalo National Park          wh_trend
# 118  198291                          Península Valdés           outlook
# 119  198291                          Península Valdés    overall_threat
# 120  198291                          Península Valdés    current_threat
# 121  198291                          Península Valdés  potential_threat
# 122  198291                          Península Valdés         prot_mgmt
# 123  198291                          Península Valdés          wh_value
# 124  198291                          Península Valdés          wh_trend
# 125  198291                          Península Valdés      biodiv_value
# 126  198291                          Península Valdés      biodiv_trend
# 127    5004                             Aldabra Atoll          language
#
#                                               value
# 0                   Good -> Good with some concerns
# 1                         Low Threat -> High Threat
# 2                         Low Threat -> High Threat
# 3                      Data Deficient -> Low Threat
# 4                                  Effective -> nan
# 5                               Low Concern -> Good
# 6                                       nan -> Good
# 7                                     nan -> Stable
# 8                                            1 -> 2
# 9                         Effective -> Some Concern
# 10   Good with some concerns -> Significant Concern
# 11                        Effective -> Some Concern
# 12                      Low Concern -> High Concern
# 13                          Stable -> Deteriorating
# 14                    Data Deficient -> Low Concern
# 15                  Data Deficient -> Deteriorating
# 16                    High Threat -> Data Deficient
# 17                    High Threat -> Data Deficient
# 18                              Low Concern -> Good
# 19                               nan -> Low Concern
# 20                            nan -> Data Deficient
# 21                  Good -> Good with some concerns
# 22                    Data Deficient -> High Threat
# 23                  Serious Concern -> Some Concern
# 24                                           1 -> 2
# 25                                           2 -> 1
# 26                  Critical -> Significant Concern
# 27                  Deteriorating -> Data Deficient
# 28                    Very Low Threat -> Low Threat
# 29                                      nan -> Good
# ..                                              ...
# 98                          Very High Threat -> nan
# 99                          Very High Threat -> nan
# 100                             Some Concern -> nan
# 101                             High Concern -> nan
# 102                            Deteriorating -> nan
# 103                             High Concern -> nan
# 104                            Deteriorating -> nan
# 105                   Low Threat -> Very Low Threat
# 106                             Low Concern -> Good
# 107                             Low Concern -> Good
# 108                       Effective -> Some Concern
# 109                       High Threat -> Low Threat
# 110                            High Concern -> Good
# 111                     Data Deficient -> Improving
# 112  Good with some concerns -> Significant Concern
# 113                       Low Threat -> High Threat
# 114                       Low Threat -> High Threat
# 115                    Effective -> Serious Concern
# 116                     Low Concern -> High Concern
# 117                         Stable -> Deteriorating
# 118                  Good with some concerns -> nan
# 119                               Low Threat -> nan
# 120                               Low Threat -> nan
# 121                               Low Threat -> nan
# 122                             Some Concern -> nan
# 123                              Low Concern -> nan
# 124                                   Stable -> nan
# 125                             High Concern -> nan
# 126                                   Stable -> nan
# 127                                          2 -> 1
#
# [128 rows x 4 columns]

# %% [markdown]
# `pd.pivot` can be used to identify site specific change for all fields. Note the `columns` argument that for each value in the column would be made a column in the resulting pivot table

# %%
# pd.pivot?

# %%
changed_stats.pivot( 'en_name', columns='column', values='value')
# Out:
# column                                                                 biodiv_trend  \
# en_name
# Aldabra Atoll                                                                  None
# Aïr and Ténéré Natural Reserves                                                None
# Bwindi Impenetrable National Park                                     nan -> Stable
# Canadian Rocky Mountain Parks                               Stable -> Deteriorating
# Cape Floral Region Protected Areas                                             None
# Carlsbad Caverns National Park                          Data Deficient -> Improving
# Caves of Aggtelek Karst and Slovak Karst                                       None
# Coiba National Park and its Special Zone of Mar...                             None
# Dinosaur Provincial Park                                                       None
# Dong Phayayen-Khao Yai Forest Complex                                          None
# East Rennell                                                                   None
# Henderson Island                                                               None
# Historic Sanctuary of Machu Picchu                             Deteriorating -> nan
# Ibiza, Biodiversity and Culture                                                None
# Ichkeul National Park                                                          None
# Jeju Volcanic Island and Lava Tubes                                   nan -> Stable
# Kilimanjaro National Park                           Data Deficient -> Deteriorating
# Lake Turkana National Parks                                                    None
# Nahanni National Park                                                          None
# Ngorongoro Conservation Area                                  nan -> Data Deficient
# Península Valdés                                                      Stable -> nan
# Pitons, cirques and remparts of Reunion Island                                 None
# Puerto-Princesa Subterranean River National Park                               None
# Rainforests of the Atsinanana                                                  None
# Rwenzori Mountains National Park                                               None
# Selous Game Reserve                                           nan -> Data Deficient
# Simien National Park                                                           None
# Socotra Archipelago                                            nan -> Deteriorating
# Tassili n'Ajjer                                                                None
# Tsingy de Bemaraha Strict Nature Reserve                              nan -> Stable
# Vallée de Mai Nature Reserve                                                   None
# Vredefort Dome                                                                 None
# Wadi Al-Hitan (Whale Valley)                                                   None
# Wadi Rum Protected Area                                    Data Deficient -> Stable
# Waterton Glacier International Peace Park                          nan -> Improving
# Wood Buffalo National Park                                                     None
# Yellowstone National Park                               Data Deficient -> Improving
# Škocjan Caves                                                                  None
#
# column                                                               biodiv_value  \
# en_name
# Aldabra Atoll                                                                None
# Aïr and Ténéré Natural Reserves                                              None
# Bwindi Impenetrable National Park                           nan -> Data Deficient
# Canadian Rocky Mountain Parks                         Low Concern -> High Concern
# Cape Floral Region Protected Areas                                           None
# Carlsbad Caverns National Park                        High Concern -> Low Concern
# Caves of Aggtelek Karst and Slovak Karst                                     None
# Coiba National Park and its Special Zone of Mar...                           None
# Dinosaur Provincial Park                                      Low Concern -> Good
# Dong Phayayen-Khao Yai Forest Complex                                        None
# East Rennell                                                                 None
# Henderson Island                                                             None
# Historic Sanctuary of Machu Picchu                            High Concern -> nan
# Ibiza, Biodiversity and Culture                                              None
# Ichkeul National Park                                                        None
# Jeju Volcanic Island and Lava Tubes                                   nan -> Good
# Kilimanjaro National Park                           Data Deficient -> Low Concern
# Lake Turkana National Parks                                                  None
# Nahanni National Park                                                        None
# Ngorongoro Conservation Area                                   nan -> Low Concern
# Península Valdés                                              High Concern -> nan
# Pitons, cirques and remparts of Reunion Island                               None
# Puerto-Princesa Subterranean River National Park                             None
# Rainforests of the Atsinanana                                                None
# Rwenzori Mountains National Park                                             None
# Selous Game Reserve                                         nan -> Data Deficient
# Simien National Park                                                         None
# Socotra Archipelago                                           nan -> High Concern
# Tassili n'Ajjer                                                              None
# Tsingy de Bemaraha Strict Nature Reserve                              nan -> Good
# Vallée de Mai Nature Reserve                                                 None
# Vredefort Dome                                                               None
# Wadi Al-Hitan (Whale Valley)                                                 None
# Wadi Rum Protected Area                                                      None
# Waterton Glacier International Peace Park                      nan -> Low Concern
# Wood Buffalo National Park                                                   None
# Yellowstone National Park                                    High Concern -> Good
# Škocjan Caves                                                                None
#
# column                                                               current_threat  \
# en_name
# Aldabra Atoll                                                                  None
# Aïr and Ténéré Natural Reserves                                                None
# Bwindi Impenetrable National Park                                              None
# Canadian Rocky Mountain Parks                             Low Threat -> High Threat
# Cape Floral Region Protected Areas                                             None
# Carlsbad Caverns National Park                                                 None
# Caves of Aggtelek Karst and Slovak Karst              Very Low Threat -> Low Threat
# Coiba National Park and its Special Zone of Mar...  High Threat -> Very High Threat
# Dinosaur Provincial Park                                                       None
# Dong Phayayen-Khao Yai Forest Complex                                          None
# East Rennell                                                                   None
# Henderson Island                                                               None
# Historic Sanctuary of Machu Picchu                          Very High Threat -> nan
# Ibiza, Biodiversity and Culture                                  High Threat -> nan
# Ichkeul National Park                                                          None
# Jeju Volcanic Island and Lava Tubes                                            None
# Kilimanjaro National Park                                                      None
# Lake Turkana National Parks                                                    None
# Nahanni National Park                                                          None
# Ngorongoro Conservation Area                                                   None
# Península Valdés                                                  Low Threat -> nan
# Pitons, cirques and remparts of Reunion Island                   High Threat -> nan
# Puerto-Princesa Subterranean River National Park                               None
# Rainforests of the Atsinanana                                                  None
# Rwenzori Mountains National Park                                               None
# Selous Game Reserve                                                            None
# Simien National Park                                                           None
# Socotra Archipelago                                                            None
# Tassili n'Ajjer                                       High Threat -> Data Deficient
# Tsingy de Bemaraha Strict Nature Reserve                  Low Threat -> High Threat
# Vallée de Mai Nature Reserve                                                   None
# Vredefort Dome                                                                 None
# Wadi Al-Hitan (Whale Valley)                                                   None
# Wadi Rum Protected Area                                                        None
# Waterton Glacier International Peace Park                                      None
# Wood Buffalo National Park                                                     None
# Yellowstone National Park                                                      None
# Škocjan Caves                                             Low Threat -> High Threat
#
# column                                             language  \
# en_name
# Aldabra Atoll                                        2 -> 1
# Aïr and Ténéré Natural Reserves                      1 -> 2
# Bwindi Impenetrable National Park                      None
# Canadian Rocky Mountain Parks                          None
# Cape Floral Region Protected Areas                     None
# Carlsbad Caverns National Park                         None
# Caves of Aggtelek Karst and Slovak Karst               None
# Coiba National Park and its Special Zone of Mar...     None
# Dinosaur Provincial Park                               None
# Dong Phayayen-Khao Yai Forest Complex                  None
# East Rennell                                           None
# Henderson Island                                       None
# Historic Sanctuary of Machu Picchu                     None
# Ibiza, Biodiversity and Culture                      1 -> 3
# Ichkeul National Park                                2 -> 1
# Jeju Volcanic Island and Lava Tubes                    None
# Kilimanjaro National Park                              None
# Lake Turkana National Parks                            None
# Nahanni National Park                                  None
# Ngorongoro Conservation Area                           None
# Península Valdés                                       None
# Pitons, cirques and remparts of Reunion Island       1 -> 2
# Puerto-Princesa Subterranean River National Park       None
# Rainforests of the Atsinanana                        1 -> 2
# Rwenzori Mountains National Park                       None
# Selous Game Reserve                                    None
# Simien National Park                                   None
# Socotra Archipelago                                    None
# Tassili n'Ajjer                                        None
# Tsingy de Bemaraha Strict Nature Reserve             1 -> 2
# Vallée de Mai Nature Reserve                           None
# Vredefort Dome                                         None
# Wadi Al-Hitan (Whale Valley)                           None
# Wadi Rum Protected Area                                None
# Waterton Glacier International Peace Park              None
# Wood Buffalo National Park                             None
# Yellowstone National Park                              None
# Škocjan Caves                                          None
#
# column                                                                                     outlook  \
# en_name
# Aldabra Atoll                                                                                 None
# Aïr and Ténéré Natural Reserves                                                               None
# Bwindi Impenetrable National Park                                                             None
# Canadian Rocky Mountain Parks                       Good with some concerns -> Significant Concern
# Cape Floral Region Protected Areas                  Good with some concerns -> Significant Concern
# Carlsbad Caverns National Park                                                                None
# Caves of Aggtelek Karst and Slovak Karst                           Good -> Good with some concerns
# Coiba National Park and its Special Zone of Mar...                                            None
# Dinosaur Provincial Park                                                                      None
# Dong Phayayen-Khao Yai Forest Complex                              Critical -> Significant Concern
# East Rennell                                                       Critical -> Significant Concern
# Henderson Island                                                                              None
# Historic Sanctuary of Machu Picchu                                      Significant Concern -> nan
# Ibiza, Biodiversity and Culture                                         Significant Concern -> nan
# Ichkeul National Park                                                                         None
# Jeju Volcanic Island and Lava Tubes                                                           None
# Kilimanjaro National Park                                                                     None
# Lake Turkana National Parks                                                                   None
# Nahanni National Park                                                                         None
# Ngorongoro Conservation Area                                                                  None
# Península Valdés                                                    Good with some concerns -> nan
# Pitons, cirques and remparts of Reunion Island                      Good with some concerns -> nan
# Puerto-Princesa Subterranean River National Park                                              None
# Rainforests of the Atsinanana                                                                 None
# Rwenzori Mountains National Park                                                              None
# Selous Game Reserve                                                                           None
# Simien National Park                                                                          None
# Socotra Archipelago                                                                           None
# Tassili n'Ajjer                                                                               None
# Tsingy de Bemaraha Strict Nature Reserve                           Good -> Good with some concerns
# Vallée de Mai Nature Reserve                                                                  None
# Vredefort Dome                                                                                None
# Wadi Al-Hitan (Whale Valley)                                       Good -> Good with some concerns
# Wadi Rum Protected Area                                                                       None
# Waterton Glacier International Peace Park                                                     None
# Wood Buffalo National Park                          Good with some concerns -> Significant Concern
# Yellowstone National Park                                                                     None
# Škocjan Caves                                                          Good -> Significant Concern
#
# column                                                               overall_threat  \
# en_name
# Aldabra Atoll                                                                  None
# Aïr and Ténéré Natural Reserves                                                None
# Bwindi Impenetrable National Park                                              None
# Canadian Rocky Mountain Parks                             Low Threat -> High Threat
# Cape Floral Region Protected Areas                                             None
# Carlsbad Caverns National Park                                                 None
# Caves of Aggtelek Karst and Slovak Karst                                       None
# Coiba National Park and its Special Zone of Mar...  High Threat -> Very High Threat
# Dinosaur Provincial Park                                                       None
# Dong Phayayen-Khao Yai Forest Complex               Very High Threat -> High Threat
# East Rennell                                                                   None
# Henderson Island                                                               None
# Historic Sanctuary of Machu Picchu                          Very High Threat -> nan
# Ibiza, Biodiversity and Culture                                  High Threat -> nan
# Ichkeul National Park                                                          None
# Jeju Volcanic Island and Lava Tubes                                            None
# Kilimanjaro National Park                                                      None
# Lake Turkana National Parks                                                    None
# Nahanni National Park                                     Low Threat -> High Threat
# Ngorongoro Conservation Area                                                   None
# Península Valdés                                                  Low Threat -> nan
# Pitons, cirques and remparts of Reunion Island                   High Threat -> nan
# Puerto-Princesa Subterranean River National Park                               None
# Rainforests of the Atsinanana                                                  None
# Rwenzori Mountains National Park                                               None
# Selous Game Reserve                                                            None
# Simien National Park                                                           None
# Socotra Archipelago                                                            None
# Tassili n'Ajjer                                       High Threat -> Data Deficient
# Tsingy de Bemaraha Strict Nature Reserve                  Low Threat -> High Threat
# Vallée de Mai Nature Reserve                                                   None
# Vredefort Dome                                            High Threat -> Low Threat
# Wadi Al-Hitan (Whale Valley)                                                   None
# Wadi Rum Protected Area                                                        None
# Waterton Glacier International Peace Park                                      None
# Wood Buffalo National Park                                Low Threat -> High Threat
# Yellowstone National Park                                                      None
# Škocjan Caves                                             Low Threat -> High Threat
#
# column                                                             potential_threat  \
# en_name
# Aldabra Atoll                                                                  None
# Aïr and Ténéré Natural Reserves                       Data Deficient -> High Threat
# Bwindi Impenetrable National Park                                              None
# Canadian Rocky Mountain Parks                                                  None
# Cape Floral Region Protected Areas                                             None
# Carlsbad Caverns National Park                                                 None
# Caves of Aggtelek Karst and Slovak Karst                                       None
# Coiba National Park and its Special Zone of Mar...                             None
# Dinosaur Provincial Park                              Low Threat -> Very Low Threat
# Dong Phayayen-Khao Yai Forest Complex                 Data Deficient -> High Threat
# East Rennell                                                                   None
# Henderson Island                                                               None
# Historic Sanctuary of Machu Picchu                          Very High Threat -> nan
# Ibiza, Biodiversity and Culture                                  High Threat -> nan
# Ichkeul National Park                                                          None
# Jeju Volcanic Island and Lava Tubes                   Very Low Threat -> Low Threat
# Kilimanjaro National Park                                                      None
# Lake Turkana National Parks                                                    None
# Nahanni National Park                                                          None
# Ngorongoro Conservation Area                                                   None
# Península Valdés                                                  Low Threat -> nan
# Pitons, cirques and remparts of Reunion Island                   High Threat -> nan
# Puerto-Princesa Subterranean River National Park          High Threat -> Low Threat
# Rainforests of the Atsinanana                                                  None
# Rwenzori Mountains National Park                                               None
# Selous Game Reserve                                                            None
# Simien National Park                                                           None
# Socotra Archipelago                                 Very High Threat -> High Threat
# Tassili n'Ajjer                                                                None
# Tsingy de Bemaraha Strict Nature Reserve               Data Deficient -> Low Threat
# Vallée de Mai Nature Reserve                                                   None
# Vredefort Dome                                            High Threat -> Low Threat
# Wadi Al-Hitan (Whale Valley)                                                   None
# Wadi Rum Protected Area                                                        None
# Waterton Glacier International Peace Park                                      None
# Wood Buffalo National Park                                Low Threat -> High Threat
# Yellowstone National Park                                 High Threat -> Low Threat
# Škocjan Caves                                       High Threat -> Very High Threat
#
# column                                                                    prot_mgmt  \
# en_name
# Aldabra Atoll                                                                  None
# Aïr and Ténéré Natural Reserves                     Serious Concern -> Some Concern
# Bwindi Impenetrable National Park                                              None
# Canadian Rocky Mountain Parks                          Effective -> Serious Concern
# Cape Floral Region Protected Areas                        Effective -> Some Concern
# Carlsbad Caverns National Park                                                 None
# Caves of Aggtelek Karst and Slovak Karst                                       None
# Coiba National Park and its Special Zone of Mar...                             None
# Dinosaur Provincial Park                                                       None
# Dong Phayayen-Khao Yai Forest Complex                                          None
# East Rennell                                                                   None
# Henderson Island                                          Effective -> Some Concern
# Historic Sanctuary of Machu Picchu                              Some Concern -> nan
# Ibiza, Biodiversity and Culture                                 Some Concern -> nan
# Ichkeul National Park                                                          None
# Jeju Volcanic Island and Lava Tubes                                            None
# Kilimanjaro National Park                                                      None
# Lake Turkana National Parks                                                    None
# Nahanni National Park                                     Effective -> Some Concern
# Ngorongoro Conservation Area                                                   None
# Península Valdés                                                Some Concern -> nan
# Pitons, cirques and remparts of Reunion Island                     Effective -> nan
# Puerto-Princesa Subterranean River National Park                               None
# Rainforests of the Atsinanana                                                  None
# Rwenzori Mountains National Park                          Effective -> Some Concern
# Selous Game Reserve                                                            None
# Simien National Park                                                           None
# Socotra Archipelago                                 Some Concern -> Serious Concern
# Tassili n'Ajjer                                                                None
# Tsingy de Bemaraha Strict Nature Reserve                           Effective -> nan
# Vallée de Mai Nature Reserve                                                   None
# Vredefort Dome                                                                 None
# Wadi Al-Hitan (Whale Valley)                                                   None
# Wadi Rum Protected Area                                   Effective -> Some Concern
# Waterton Glacier International Peace Park                                      None
# Wood Buffalo National Park                             Effective -> Serious Concern
# Yellowstone National Park                                                      None
# Škocjan Caves                                             Effective -> Some Concern
#
# column                                                                     wh_trend  \
# en_name
# Aldabra Atoll                                                                  None
# Aïr and Ténéré Natural Reserves                                                None
# Bwindi Impenetrable National Park                                              None
# Canadian Rocky Mountain Parks                               Stable -> Deteriorating
# Cape Floral Region Protected Areas                          Stable -> Deteriorating
# Carlsbad Caverns National Park                                                 None
# Caves of Aggtelek Karst and Slovak Karst                                       None
# Coiba National Park and its Special Zone of Mar...                             None
# Dinosaur Provincial Park                                                       None
# Dong Phayayen-Khao Yai Forest Complex               Data Deficient -> Deteriorating
# East Rennell                                        Deteriorating -> Data Deficient
# Henderson Island                                                               None
# Historic Sanctuary of Machu Picchu                             Deteriorating -> nan
# Ibiza, Biodiversity and Culture                                Deteriorating -> nan
# Ichkeul National Park                                                          None
# Jeju Volcanic Island and Lava Tubes                                            None
# Kilimanjaro National Park                                                      None
# Lake Turkana National Parks                         Data Deficient -> Deteriorating
# Nahanni National Park                                                          None
# Ngorongoro Conservation Area                                                   None
# Península Valdés                                                      Stable -> nan
# Pitons, cirques and remparts of Reunion Island                        Stable -> nan
# Puerto-Princesa Subterranean River National Park                               None
# Rainforests of the Atsinanana                                                  None
# Rwenzori Mountains National Park                                               None
# Selous Game Reserve                                                            None
# Simien National Park                                    Data Deficient -> Improving
# Socotra Archipelago                                                            None
# Tassili n'Ajjer                                                                None
# Tsingy de Bemaraha Strict Nature Reserve                                       None
# Vallée de Mai Nature Reserve                               Data Deficient -> Stable
# Vredefort Dome                                                                 None
# Wadi Al-Hitan (Whale Valley)                                                   None
# Wadi Rum Protected Area                                    Data Deficient -> Stable
# Waterton Glacier International Peace Park                                      None
# Wood Buffalo National Park                                  Stable -> Deteriorating
# Yellowstone National Park                                                      None
# Škocjan Caves                                       Data Deficient -> Deteriorating
#
# column                                                                 wh_value
# en_name
# Aldabra Atoll                                                              None
# Aïr and Ténéré Natural Reserves                                            None
# Bwindi Impenetrable National Park                                          None
# Canadian Rocky Mountain Parks                              Good -> High Concern
# Cape Floral Region Protected Areas                  Low Concern -> High Concern
# Carlsbad Caverns National Park                                             None
# Caves of Aggtelek Karst and Slovak Karst                                   None
# Coiba National Park and its Special Zone of Mar...                         None
# Dinosaur Provincial Park                                    Low Concern -> Good
# Dong Phayayen-Khao Yai Forest Complex                  Critical -> High Concern
# East Rennell                                                               None
# Henderson Island                                                           None
# Historic Sanctuary of Machu Picchu                          High Concern -> nan
# Ibiza, Biodiversity and Culture                             High Concern -> nan
# Ichkeul National Park                                                      None
# Jeju Volcanic Island and Lava Tubes                                        None
# Kilimanjaro National Park                                                  None
# Lake Turkana National Parks                                                None
# Nahanni National Park                                                      None
# Ngorongoro Conservation Area                                               None
# Península Valdés                                             Low Concern -> nan
# Pitons, cirques and remparts of Reunion Island               Low Concern -> nan
# Puerto-Princesa Subterranean River National Park                           None
# Rainforests of the Atsinanana                                              None
# Rwenzori Mountains National Park                                           None
# Selous Game Reserve                                                        None
# Simien National Park                                                       None
# Socotra Archipelago                                                        None
# Tassili n'Ajjer                                             Low Concern -> Good
# Tsingy de Bemaraha Strict Nature Reserve                    Low Concern -> Good
# Vallée de Mai Nature Reserve                                               None
# Vredefort Dome                                                             None
# Wadi Al-Hitan (Whale Valley)                                               None
# Wadi Rum Protected Area                                     Low Concern -> Good
# Waterton Glacier International Peace Park                                  None
# Wood Buffalo National Park                          Low Concern -> High Concern
# Yellowstone National Park                                                  None
# Škocjan Caves                                               Good -> Low Concern

# %% [markdown]
# SQL term `group by` are equivalent to the pivot table `index`.

# %%
pd.pivot_table(changed_stats, values='wdpaid', index='value', aggfunc=np.count_nonzero)
# Out:
#                                                 wdpaid
# value
# 1 -> 2                                               4
# 1 -> 3                                               1
# 2 -> 1                                               2
# Critical -> High Concern                             1
# Critical -> Significant Concern                      2
# Data Deficient -> Deteriorating                      4
# Data Deficient -> High Threat                        2
# Data Deficient -> Improving                          3
# Data Deficient -> Low Concern                        1
# Data Deficient -> Low Threat                         1
# Data Deficient -> Stable                             3
# Deteriorating -> Data Deficient                      1
# Deteriorating -> nan                                 3
# Effective -> Serious Concern                         2
# Effective -> Some Concern                            6
# Effective -> nan                                     2
# Good -> Good with some concerns                      3
# Good -> High Concern                                 1
# Good -> Low Concern                                  1
# Good -> Significant Concern                          1
# Good with some concerns -> Significant Concern       3
# Good with some concerns -> nan                       2
# High Concern -> Good                                 1
# High Concern -> Low Concern                          1
# High Concern -> nan                                  4
# High Threat -> Data Deficient                        2
# High Threat -> Low Threat                            4
# High Threat -> Very High Threat                      3
# High Threat -> nan                                   6
# Low Concern -> Good                                  5
# Low Concern -> High Concern                          3
# Low Concern -> nan                                   2
# Low Threat -> High Threat                            9
# Low Threat -> Very Low Threat                        1
# Low Threat -> nan                                    3
# Serious Concern -> Some Concern                      1
# Significant Concern -> nan                           2
# Some Concern -> Serious Concern                      1
# Some Concern -> nan                                  3
# Stable -> Deteriorating                              4
# Stable -> nan                                        3
# Very High Threat -> High Threat                      2
# Very High Threat -> nan                              3
# Very Low Threat -> Low Threat                        2
# nan -> Data Deficient                                4
# nan -> Deteriorating                                 1
# nan -> Good                                          2
# nan -> High Concern                                  1
# nan -> Improving                                     1
# nan -> Low Concern                                   2
# nan -> Stable                                        3

# %% [markdown]
# ## Utility functions

# %% [markdown]
# Find rows in threat table

# %%
def find_threat_rows(wdpaid, cycle, current=True):
    if current:
        table = current_threat
    else:
        table = potential_threat
        
    return table[(table.assessment_cycle == cycle) & (table.wdpa_id == wdpaid)]

# %%
find_threat_rows(191, 2014)
# Out:
#       wdpa_id screenname     status      stage            name_en  \
# 1156      191      elena  Completed  Published  Galápagos Islands
# 1158      191      elena  Completed  Published  Galápagos Islands
# 1159      191      elena  Completed  Published  Galápagos Islands
# 1160      191      elena  Completed  Published  Galápagos Islands
# 1495      191      elena  Completed  Published  Galápagos Islands
#
#                                        threat_category  \
# 1156              Transportation and Service Corridors
# 1158  Invasive and Other Problematic Species and Genes
# 1159                  Human Intrusions and Disturbance
# 1160                           Biological Resource Use
# 1495                 Climate Change and Severe Weather
#
#                          threat_sub_category            rating  inside_site  \
# 1156                          Shipping Lanes       High Threat          1.0
# 1158      Invasive Non-Native/ Alien Species  Very High Threat          1.0
# 1159           Tourism/ visitors/ recreation  Very High Threat          1.0
# 1160  Fishing / Harvesting Aquatic Resources       High Threat          1.0
# 1495                    Temperature extremes       High Threat          1.0
#
#       outside_site  assessment_version_id  assessment_cycle
# 1156           1.0                   5742              2014
# 1158           0.0                   5742              2014
# 1159           0.0                   5742              2014
# 1160           0.0                   5742              2014
# 1495           0.0                   5742              2014

# %%
potential_threat.head()
# Out:
#    wdpa_id screenname     status      stage  \
# 0   478640      elena  Completed  Published
# 1    26653      elena  Completed  Published
# 2    26653      elena  Completed  Published
# 3    26653      elena  Completed  Published
# 4    26653      elena  Completed  Published
#
#                                     name_en  \
# 0                      Hierapolis-Pamukkale
# 1  Tsingy de Bemaraha Strict Nature Reserve
# 2  Tsingy de Bemaraha Strict Nature Reserve
# 3  Tsingy de Bemaraha Strict Nature Reserve
# 4  Tsingy de Bemaraha Strict Nature Reserve
#
#                      threat_category               threat_sub_category  \
# 0                  Geological Events             Earthquakes/ Tsunamis
# 1  Climate Change and Severe Weather      Habitat Shifting/ Alteration
# 2  Climate Change and Severe Weather                          Droughts
# 3  Climate Change and Severe Weather              Temperature extremes
# 4       Energy Production and Mining  Oil/ Gas exploration/development
#
#                potential_threat          rating  inside_site  outside_site  \
# 0                   Earthquakes      Low Threat          1.0           0.0
# 1              Habitat shifting  Data Deficient          0.0           0.0
# 2  Changes to rainfall patterns  Data Deficient          0.0           0.0
# 3           Temperature changes  Data Deficient          0.0           0.0
# 4                   Oil and gas  Data Deficient          0.0           0.0
#
#    assessment_cycle
# 0              2014
# 1              2014
# 2              2014
# 3              2014
# 4              2014

# %% [markdown]
# Use a python closure to generate a set of utility functions that find rows in any given table, based on the `wdpaid` and the `assessnment_cycle` fields

# %%
def gen_find_df_records(df):
    # generate functions for inspection
    if 'wdpa_id' not in df.columns.tolist() or 'assessment_cycle' not in df.columns.tolist():
        raise Exception('wdpa_id or assessment_cycle not present in the input dataframe')
    
    def find_df_records(wdpaid, cycle):
        return df[(df.assessment_cycle == cycle) & (df.wdpa_id == wdpaid)]
        
    return find_df_records

# %%
find_pm = gen_find_df_records(protection_management)

# %%
find_pm(191, 2014)
# Out:
#       wdpa_id screenname     status      stage            name_en  \
# 2394      191      elena  Completed  Published  Galápagos Islands
# 2395      191      elena  Completed  Published  Galápagos Islands
# 2396      191      elena  Completed  Published  Galápagos Islands
# 2397      191      elena  Completed  Published  Galápagos Islands
# 2398      191      elena  Completed  Published  Galápagos Islands
# 2399      191      elena  Completed  Published  Galápagos Islands
# 2400      191      elena  Completed  Published  Galápagos Islands
# 2401      191      elena  Completed  Published  Galápagos Islands
# 2402      191      elena  Completed  Published  Galápagos Islands
# 2403      191      elena  Completed  Published  Galápagos Islands
# 2404      191      elena  Completed  Published  Galápagos Islands
# 2405      191      elena  Completed  Published  Galápagos Islands
# 2406      191      elena  Completed  Published  Galápagos Islands
# 2407      191      elena  Completed  Published  Galápagos Islands
#
#                                                   topic        pm_rating  \
# 2394  Relationships with local people (including sta...     Some Concern
# 2395                                    Legal framework     Some Concern
# 2396  Integration into regional and national plannin...     Some Concern
# 2397  Management system (for transboundary/serial pr...        Effective
# 2398                           Management effectiveness     Some Concern
# 2399  Implementation of Committee decisions and reco...     Some Concern
# 2400                                         Boundaries        Effective
# 2401                                Sustainable finance        Effective
# 2402                     Staff training and development  Serious Concern
# 2403                                    Sustainable use     Some Concern
# 2404              Education and interpretation programs        Effective
# 2405                  Tourism and visitation management     Some Concern
# 2406                                         Monitoring        Effective
# 2407                                           Research        Effective
#
#       assessment_cycle
# 2394              2014
# 2395              2014
# 2396              2014
# 2397              2014
# 2398              2014
# 2399              2014
# 2400              2014
# 2401              2014
# 2402              2014
# 2403              2014
# 2404              2014
# 2405              2014
# 2406              2014
# 2407              2014

# %%
find_overall = gen_find_df_records(overall)
find_current_threat = gen_find_df_records(current_threat)
find_potential_threat = gen_find_df_records(potential_threat)
find_protection_management = gen_find_df_records(protection_management)
find_value_current_threat = gen_find_df_records(value_current_threat)
find_value_potential_threat = gen_find_df_records(value_potential_threat)

# %%
find_overall(191,2014)
# Out:
#      wdpa_id screenname     status      stage            name_en  \
# 177      191      elena  Completed  Published  Galápagos Islands
#
#                  outlook    overall_threat    current_threat  \
# 177  Significant Concern  Very High Threat  Very High Threat
#
#      potential_threat  prot_mgmt      wh_value       wh_trend  biodiv_value  \
# 177  Very High Threat  Effective  High Concern  Deteriorating  High Concern
#
#       biodiv_trend  language  assessment_cycle
# 177  Deteriorating         1              2014

# %%
find_current_threat(191,2014)
# Out:
#       wdpa_id screenname     status      stage            name_en  \
# 1156      191      elena  Completed  Published  Galápagos Islands
# 1158      191      elena  Completed  Published  Galápagos Islands
# 1159      191      elena  Completed  Published  Galápagos Islands
# 1160      191      elena  Completed  Published  Galápagos Islands
# 1495      191      elena  Completed  Published  Galápagos Islands
#
#                                        threat_category  \
# 1156              Transportation and Service Corridors
# 1158  Invasive and Other Problematic Species and Genes
# 1159                  Human Intrusions and Disturbance
# 1160                           Biological Resource Use
# 1495                 Climate Change and Severe Weather
#
#                          threat_sub_category            rating  inside_site  \
# 1156                          Shipping Lanes       High Threat          1.0
# 1158      Invasive Non-Native/ Alien Species  Very High Threat          1.0
# 1159           Tourism/ visitors/ recreation  Very High Threat          1.0
# 1160  Fishing / Harvesting Aquatic Resources       High Threat          1.0
# 1495                    Temperature extremes       High Threat          1.0
#
#       outside_site  assessment_version_id  assessment_cycle
# 1156           1.0                   5742              2014
# 1158           0.0                   5742              2014
# 1159           0.0                   5742              2014
# 1160           0.0                   5742              2014
# 1495           0.0                   5742              2014

# %%
find_current_threat(191, 2017)
# Out:
#       wdpa_id screenname       status       stage            name_en  \
# 1646      191      wendy  In Progress  Assessment  Galápagos Islands
# 1754      191      wendy  In Progress  Assessment  Galápagos Islands
# 1755      191      wendy  In Progress  Assessment  Galápagos Islands
# 1756      191      wendy  In Progress  Assessment  Galápagos Islands
# 1757      191      wendy  In Progress  Assessment  Galápagos Islands
#
#                                        threat_category  \
# 1646              Transportation and Service Corridors
# 1754  Invasive and Other Problematic Species and Genes
# 1755                  Human Intrusions and Disturbance
# 1756                           Biological Resource Use
# 1757                 Climate Change and Severe Weather
#
#                          threat_sub_category            rating  inside_site  \
# 1646                          Shipping Lanes       High Threat          1.0
# 1754      Invasive Non-Native/ Alien Species  Very High Threat          1.0
# 1755           Tourism/ visitors/ recreation  Very High Threat          1.0
# 1756  Fishing / Harvesting Aquatic Resources       High Threat          1.0
# 1757                    Temperature extremes       High Threat          1.0
#
#       outside_site  assessment_version_id  assessment_cycle
# 1646           1.0                   6966              2017
# 1754           0.0                   6966              2017
# 1755           0.0                   6966              2017
# 1756           0.0                   6966              2017
# 1757           0.0                   6966              2017

# %%
# potential threat of id 2008, in assessment cycle 2014
find_potential_threat(2008, 2014)
# Out:
#      wdpa_id screenname     status      stage            name_en  \
# 394     2008      elena  Completed  Published  Bialowieza Forest
# 395     2008      elena  Completed  Published  Bialowieza Forest
#
#                        threat_category     threat_sub_category  \
# 394  Climate Change and Severe Weather    Temperature extremes
# 395       Natural System Modifications  Fire/ Fire Suppression
#
#                              potential_threat          rating  inside_site  \
# 394  Changes in temperature and precipitation  Data Deficient          1.0
# 395                              Forest fires      Low Threat          1.0
#
#      outside_site  assessment_cycle
# 394           1.0              2014
# 395           1.0              2014

# %%
# verify the function from factory produces expected results
potential_threat[(potential_threat.assessment_cycle == 2014) & (potential_threat.wdpa_id == 2008)]
# Out:
#      wdpa_id screenname     status      stage            name_en  \
# 394     2008      elena  Completed  Published  Bialowieza Forest
# 395     2008      elena  Completed  Published  Bialowieza Forest
#
#                        threat_category     threat_sub_category  \
# 394  Climate Change and Severe Weather    Temperature extremes
# 395       Natural System Modifications  Fire/ Fire Suppression
#
#                              potential_threat          rating  inside_site  \
# 394  Changes in temperature and precipitation  Data Deficient          1.0
# 395                              Forest fires      Low Threat          1.0
#
#      outside_site  assessment_cycle
# 394           1.0              2014
# 395           1.0              2014

# %%
find_current_threat(191, 2014)
# Out:
#       wdpa_id screenname     status      stage            name_en  \
# 1156      191      elena  Completed  Published  Galápagos Islands
# 1158      191      elena  Completed  Published  Galápagos Islands
# 1159      191      elena  Completed  Published  Galápagos Islands
# 1160      191      elena  Completed  Published  Galápagos Islands
# 1495      191      elena  Completed  Published  Galápagos Islands
#
#                                        threat_category  \
# 1156              Transportation and Service Corridors
# 1158  Invasive and Other Problematic Species and Genes
# 1159                  Human Intrusions and Disturbance
# 1160                           Biological Resource Use
# 1495                 Climate Change and Severe Weather
#
#                          threat_sub_category            rating  inside_site  \
# 1156                          Shipping Lanes       High Threat          1.0
# 1158      Invasive Non-Native/ Alien Species  Very High Threat          1.0
# 1159           Tourism/ visitors/ recreation  Very High Threat          1.0
# 1160  Fishing / Harvesting Aquatic Resources       High Threat          1.0
# 1495                    Temperature extremes       High Threat          1.0
#
#       outside_site  assessment_version_id  assessment_cycle
# 1156           1.0                   5742              2014
# 1158           0.0                   5742              2014
# 1159           0.0                   5742              2014
# 1160           0.0                   5742              2014
# 1495           0.0                   5742              2014

# %% [markdown]
# ## Idea: an improved way to calculate outlook
#
# One inherent weakness of the Outlook process is the qualitative methods employed to assess outlook and its three components, values, threats and management. While contrast and variation of rating is possible by broad categories, i.e. High, Very High to Low, they are not accurate and do not capture differences that may be subtle but signifcant, within and across sites. Additionally, the variety of assessors and reviewers, despite the benefits brought by the diversity and broad coverage of talent pools from across the globe, may also undermine the impartiality of assessments when criteria may be subjectively or inconsistently applied. This is further restricted by the need to classify into limited categories. At this late stage, little can be done to remedy or adjust the uncertainty and the improvement may require systematically revisiting the methodology and significant restructures, notably requiring more quantitative measures. It is important that we do not overlook this exercise as it determines the long term viability as a comparable, impartial metric that can measure the wellbing and outlook for natural World Heritage sites.
#
# What could be addressed at this point however is the weak linkage between the assessments of values, threats and management and the final outlook assessment. Though logics exist there is no apparent systematic way of determining the final outlook.
#
# ### Finding associations between variables
#
# For example that of prot_management score and overall outlook rating

# %%
# install scipy if not available
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in /Users/ys/Documents/git/pyenv/lib/python2.7/site-packages
# Requirement already satisfied: numpy>=1.8.2 in /Users/ys/Documents/git/pyenv/lib/python2.7/site-packages (from scipy)

# %% [markdown]
# Check unique values and turn text field into catgorical variables with order. The idea is to test whether or not the final outlooking is in any way dependent on other fields, e.g. protections and management, threats and values etc.

# %%
overall.outlook.unique()
# Out:
# array([u'Good', u'Significant Concern', u'Good with some concerns',
#        u'Critical', nan], dtype=object)

# %%
overall.prot_mgmt.unique()
# Out:
# array([u'Highly Effective', u'Effective', u'Serious Concern',
#        u'Some Concern', nan], dtype=object)

# %%
overall.overall_threat.unique()
# Out:
# array([u'Very Low Threat', u'Low Threat', u'High Threat',
#        u'Very High Threat', u'Data Deficient', nan], dtype=object)

# %%
overall.current_threat.unique()
# Out:
# array([u'Very Low Threat', u'Low Threat', u'High Threat',
#        u'Very High Threat', u'Data Deficient', nan], dtype=object)

# %%
overall.potential_threat.unique()
# Out:
# array([u'Low Threat', u'Data Deficient', nan, u'High Threat',
#        u'Very High Threat', u'Very Low Threat'], dtype=object)

# %%
overall.wh_value.unique()
# Out:
# array([u'Good', u'Low Concern', u'High Concern', u'Critical', nan], dtype=object)

# %%
overall.head(40)
# Out:
#       wdpa_id screenname     status       stage  \
# 0      124388      elena  Completed   Published
# 1       26653      elena  Completed   Published
# 2       20171      elena  Completed   Published
# 3       61608       alok  Completed   Published
# 4      902347      elena  Completed   Published
# 5        4328      elena  Completed   Published
# 6       10904      elena  Completed   Published
# 7      145583      elena  Completed   Published
# 8      902373      elena  Completed   Published
# 9      903134      elena  Completed   Published
# 10      17761      elena  Completed   Published
# 11       2580      elena  Completed   Published
# 12       4999      elena  Completed   Published
# 13     124389      elena  Completed   Published
# 14       2010      elena  Completed   Published
# 15     902487      elena  Completed   Published
# 16      67727      elena  Completed  Translated
# 17       4322      elena  Completed  Translated
# 18     478640      elena  Completed   Published
# 19     168242      elena  Completed   Published
# 20     900630      elena  Completed   Published
# 21  555512001      elena  Completed   Published
# 22      10745      elena  Completed   Published
# 23     198298      elena  Completed   Published
# 24     220292      elena  Completed   Published
# 25      18862      elena  Completed   Published
# 26       4326      elena  Completed   Published
# 27     903133      elena  Completed   Published
# 28  555556046      elena  Completed   Published
# 29     903129      elena  Completed   Published
# 30     478637      elena  Completed   Published
# 31     902481      elena  Completed    Approved
# 32     903130      elena  Completed   Published
# 33       2570      elena  Completed   Published
# 34     903136      elena  Completed   Published
# 35     145586      elena  Completed   Published
# 36       4327      elena  Completed   Published
# 37     902899      elena  Completed   Published
# 38      26649      elena  Completed   Published
# 39      20388      elena  Completed   Published
#
#                                               name_en  \
# 0                                       Laponian Area
# 1            Tsingy de Bemaraha Strict Nature Reserve
# 2            Cliff of Bandiagara (Land of the Dogons)
# 3                    Rwenzori Mountains National Park
# 4                  Cape Floral Region Protected Areas
# 5                          Kahuzi-Biéga National Park
# 6                           Lake Malawi National Park
# 7                    Morne Trois Pitons National Park
# 8                                  Ilulissat Icefjord
# 9   Lagoons of New Caledonia: Reef Diversity and A...
# 10                          Kilimanjaro National Park
# 11                         Niokolo-Koba National Park
# 12                      Tassili n'Ajjer National Park
# 13                             Okapi Wildlife Reserve
# 14                       Ngorongoro Conservation Area
# 15                       Wadi Al-Hitan (Whale Valley)
# 16                    Aïr and Ténéré Natural Reserves
# 17                              Ichkeul National Park
# 18                               Hierapolis-Pamukkale
# 19                                       East Rennell
# 20  Cerrado Protected Areas: Chapada dos Veadeiros...
# 21                                  Papahanaumokuakea
# 22                           Manas Wildlife Sanctuary
# 23                              Lorentz National Park
# 24                                      Kinabalu Park
# 25                                            Meteora
# 26                             Durmitor National Park
# 27                              Joggins Fossil Cliffs
# 28  El Pinacate and Gran Desierto de Altar Biosphe...
# 29  Ecosystem and Relict Cultural Landscape of Lop...
# 30  Göreme National Park and the Rock Sites of Cap...
# 31  Islands and Protected Areas of the Gulf of Cal...
# 32                Jeju Volcanic Island and Lava Tubes
# 33                        Los Glaciares National Park
# 34                    Mount Sanqingshan National Park
# 35                        Lake Turkana National Parks
# 36                              Garamba National Park
# 37                  Malpelo Fauna and Flora Sanctuary
# 38                            Tongariro National Park
# 39                        Banc d'Arguin National Park
#
#                     outlook    overall_threat    current_threat  \
# 0                      Good   Very Low Threat   Very Low Threat
# 1                      Good        Low Threat        Low Threat
# 2       Significant Concern       High Threat       High Threat
# 3   Good with some concerns        Low Threat        Low Threat
# 4   Good with some concerns       High Threat       High Threat
# 5                  Critical  Very High Threat  Very High Threat
# 6       Significant Concern       High Threat       High Threat
# 7   Good with some concerns        Low Threat        Low Threat
# 8   Good with some concerns        Low Threat        Low Threat
# 9   Good with some concerns        Low Threat       High Threat
# 10  Good with some concerns        Low Threat        Low Threat
# 11                 Critical  Very High Threat  Very High Threat
# 12  Good with some concerns       High Threat       High Threat
# 13                 Critical  Very High Threat  Very High Threat
# 14  Good with some concerns        Low Threat       High Threat
# 15                     Good        Low Threat        Low Threat
# 16                 Critical  Very High Threat  Very High Threat
# 17      Significant Concern       High Threat       High Threat
# 18  Good with some concerns       High Threat       High Threat
# 19                 Critical  Very High Threat  Very High Threat
# 20      Significant Concern       High Threat       High Threat
# 21                     Good        Low Threat        Low Threat
# 22      Significant Concern       High Threat       High Threat
# 23      Significant Concern       High Threat       High Threat
# 24  Good with some concerns        Low Threat        Low Threat
# 25  Good with some concerns        Low Threat        Low Threat
# 26      Significant Concern       High Threat       High Threat
# 27                     Good        Low Threat        Low Threat
# 28  Good with some concerns        Low Threat        Low Threat
# 29  Good with some concerns       High Threat       High Threat
# 30  Good with some concerns       High Threat       High Threat
# 31  Good with some concerns       High Threat       High Threat
# 32                     Good        Low Threat        Low Threat
# 33  Good with some concerns        Low Threat        Low Threat
# 34                     Good        Low Threat        Low Threat
# 35                 Critical  Very High Threat  Very High Threat
# 36                 Critical  Very High Threat  Very High Threat
# 37  Good with some concerns       High Threat  Very High Threat
# 38                     Good        Low Threat        Low Threat
# 39      Significant Concern       High Threat       High Threat
#
#     potential_threat         prot_mgmt      wh_value        wh_trend  \
# 0         Low Threat  Highly Effective          Good          Stable
# 1     Data Deficient         Effective   Low Concern          Stable
# 2                NaN   Serious Concern  High Concern   Deteriorating
# 3     Data Deficient         Effective   Low Concern  Data Deficient
# 4        High Threat         Effective   Low Concern          Stable
# 5        High Threat      Some Concern  High Concern  Data Deficient
# 6   Very High Threat      Some Concern  High Concern  Data Deficient
# 7        High Threat      Some Concern   Low Concern   Deteriorating
# 8        High Threat         Effective   Low Concern          Stable
# 9         Low Threat         Effective          Good          Stable
# 10               NaN         Effective   Low Concern   Deteriorating
# 11       High Threat   Serious Concern      Critical  Data Deficient
# 12               NaN      Some Concern   Low Concern          Stable
# 13        Low Threat   Serious Concern  High Concern   Deteriorating
# 14        Low Threat         Effective   Low Concern          Stable
# 15    Data Deficient         Effective          Good          Stable
# 16    Data Deficient   Serious Concern      Critical   Deteriorating
# 17    Data Deficient      Some Concern  High Concern       Improving
# 18        Low Threat      Some Concern   Low Concern  Data Deficient
# 19       High Threat   Serious Concern  High Concern   Deteriorating
# 20  Very High Threat   Serious Concern   Low Concern   Deteriorating
# 21       High Threat         Effective   Low Concern          Stable
# 22       High Threat      Some Concern  High Concern  Data Deficient
# 23       High Threat   Serious Concern   Low Concern   Deteriorating
# 24        Low Threat         Effective   Low Concern          Stable
# 25        Low Threat      Some Concern   Low Concern          Stable
# 26  Very High Threat   Serious Concern  High Concern   Deteriorating
# 27   Very Low Threat  Highly Effective          Good          Stable
# 28       High Threat         Effective   Low Concern          Stable
# 29       High Threat      Some Concern   Low Concern  Data Deficient
# 30        Low Threat         Effective   Low Concern       Improving
# 31       High Threat         Effective          Good  Data Deficient
# 32   Very Low Threat         Effective          Good          Stable
# 33        Low Threat         Effective   Low Concern   Deteriorating
# 34        Low Threat         Effective          Good  Data Deficient
# 35       High Threat   Serious Concern  High Concern  Data Deficient
# 36        Low Threat      Some Concern  High Concern  Data Deficient
# 37        Low Threat      Some Concern   Low Concern          Stable
# 38   Very Low Threat  Highly Effective          Good          Stable
# 39       High Threat      Some Concern   Low Concern   Deteriorating
#
#       biodiv_value    biodiv_trend  language  assessment_cycle
# 0              NaN             NaN         1              2014
# 1              NaN             NaN         1              2014
# 2   Data Deficient  Data Deficient         2              2014
# 3   Data Deficient  Data Deficient         1              2014
# 4              NaN             NaN         1              2014
# 5              NaN             NaN         1              2014
# 6              NaN             NaN         1              2014
# 7     High Concern   Deteriorating         1              2014
# 8      Low Concern  Data Deficient         1              2014
# 9              NaN             NaN         2              2014
# 10  Data Deficient  Data Deficient         1              2014
# 11        Critical  Data Deficient         2              2014
# 12    High Concern   Deteriorating         1              2014
# 13             NaN             NaN         1              2014
# 14             NaN             NaN         1              2014
# 15             NaN             NaN         1              2014
# 16             NaN             NaN         1              2014
# 17  Data Deficient  Data Deficient         2              2014
# 18             NaN             NaN         1              2014
# 19  Data Deficient   Deteriorating         1              2014
# 20             NaN             NaN         1              2014
# 21             NaN             NaN         1              2014
# 22  Data Deficient  Data Deficient         1              2014
# 23             NaN             NaN         1              2014
# 24             NaN             NaN         1              2014
# 25    High Concern  Data Deficient         1              2014
# 26             NaN             NaN         1              2014
# 27            Good          Stable         1              2014
# 28             NaN             NaN         1              2014
# 29             NaN             NaN         2              2014
# 30             NaN             NaN         1              2014
# 31             NaN             NaN         1              2014
# 32             NaN             NaN         1              2014
# 33    High Concern   Deteriorating         1              2014
# 34  Data Deficient  Data Deficient         1              2014
# 35             NaN             NaN         1              2014
# 36            Good          Stable         1              2014
# 37     Low Concern  Data Deficient         1              2014
# 38             NaN             NaN         1              2014
# 39             NaN             NaN         1              2014

# %%
overall_outlook_cat = overall.outlook.astype('category', \
                                             categories=['Critical', 'Significant Concern', 'Good with some concerns', 'Good'],\
                                             ordered=True)

# %%
overall_threat_cat = overall.overall_threat.astype('category', \
                                                   categories=['Very High Threat', 'High Threat','Low Threat', 'Very Low Threat'],\
                                                   ordered=True)

# %%
# for testing the effect of reverse ordering
overall_threat_cat_reverse = overall.overall_threat.astype('category', \
                                                   categories=['Very Low Threat', 'Low Threat','High Threat', 'Very High Threat'],\
                                                   ordered=True)

# %%
overall_pm_cat = overall.prot_mgmt.astype('category',\
                                          categories=['Serious Concern', 'Some Concern','Effective', 'Highly Effective'], \
                                          ordered=True)

# %%
overall_value_cat = overall.wh_value.astype('category',\
                                          categories=['Critical', 'High Concern','Low Concern','Good'], \
                                          ordered=True)

# %%
overall_outlook_cat.cat.codes.head(20)
# Out:
# 0     3
# 1     3
# 2     1
# 3     2
# 4     2
# 5     0
# 6     1
# 7     2
# 8     2
# 9     2
# 10    2
# 11    0
# 12    2
# 13    0
# 14    2
# 15    3
# 16    0
# 17    1
# 18    2
# 19    0
# dtype: int8

# %%
overall_outlook_cat.head(20)
# Out:
# 0                        Good
# 1                        Good
# 2         Significant Concern
# 3     Good with some concerns
# 4     Good with some concerns
# 5                    Critical
# 6         Significant Concern
# 7     Good with some concerns
# 8     Good with some concerns
# 9     Good with some concerns
# 10    Good with some concerns
# 11                   Critical
# 12    Good with some concerns
# 13                   Critical
# 14    Good with some concerns
# 15                       Good
# 16                   Critical
# 17        Significant Concern
# 18    Good with some concerns
# 19                   Critical
# Name: outlook, dtype: category
# Categories (4, object): [Critical < Significant Concern < Good with some concerns < Good]

# %%
overall_threat_cat.cat.codes.head(20)
# Out:
# 0     3
# 1     2
# 2     1
# 3     2
# 4     1
# 5     0
# 6     1
# 7     2
# 8     2
# 9     2
# 10    2
# 11    0
# 12    1
# 13    0
# 14    2
# 15    2
# 16    0
# 17    1
# 18    1
# 19    0
# dtype: int8

# %%
overall_threat_cat.head(20)
# Out:
# 0      Very Low Threat
# 1           Low Threat
# 2          High Threat
# 3           Low Threat
# 4          High Threat
# 5     Very High Threat
# 6          High Threat
# 7           Low Threat
# 8           Low Threat
# 9           Low Threat
# 10          Low Threat
# 11    Very High Threat
# 12         High Threat
# 13    Very High Threat
# 14          Low Threat
# 15          Low Threat
# 16    Very High Threat
# 17         High Threat
# 18         High Threat
# 19    Very High Threat
# Name: overall_threat, dtype: category
# Categories (4, object): [Very High Threat < High Threat < Low Threat < Very Low Threat]

# %%
overall_outlook_cat.min()
# Out:
# nan

# %%
overall_outlook_cat.max()
# Out:
# 'Good'

# %% [markdown]
# Check the current association between variables

# %%
from scipy import stats

# %% [markdown]
# Add jitter, smaller delta x and y, to better see categorical relationships. Create an array of random numbers on normal distribution of size `len(array)` multiple by a scale factor based on the `max(array)` and `min(array)` values.

# %%
jitter_x = 0.05 * np.random.randn(len(overall_threat_cat.cat.codes)) * (max(overall_threat_cat.cat.codes) - min(overall_threat_cat.cat.codes))
jitter_y = 0.05 * np.random.randn(len(overall_outlook_cat.cat.codes)) * (max(overall_outlook_cat.cat.codes) - min(overall_outlook_cat.cat.codes))

# %%
plt.scatter(overall_threat_cat.cat.codes + jitter_x, overall_outlook_cat.cat.codes + jitter_y)

# %% [markdown]
# Seeing the above graph, though a general linear relationship can be determined, some interesting outliers are present. For example, there are three 1-3, meaning high threats but still good outlook. 3-2, low threats but good with concern outlooks.
# Note -1 are NAN records.

# %% [markdown]
# More quantitative metric
#
# [Spearman's rho](https://en.wikipedia.org/wiki/Spearman%27s_rank_correlation_coefficient) is a non-parametric coefficient for categorical variables. rho=0 means no apparent association, -1 negative perfect monotone, +1 postive perfect. Scipy has an implementation of [spearmanr](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.spearmanr.html)
#
# Understandbly negative relationship between overall threats and overall outlook. The less signficant threat, and better outlook. Noting the order of all categorical variables above is from *bad* to *good*, in other words, such a relationship would show up as positive, i.e lower threat - good outlook. This is purely due to the way data is ordered
#
# Convert categorical data into numericals for scipy analysis, `series.cat.codes`

# %%
# threat and outlook
stats.spearmanr(overall_threat_cat.cat.codes, overall_outlook_cat.cat.codes)
# Out:
# SpearmanrResult(correlation=0.81011644618186585, pvalue=7.6216009081686093e-91)

# %%
# threat and outlook: illustrate the effect of reverse ordering
stats.spearmanr(overall_threat_cat_reverse.cat.codes, overall_outlook_cat.cat.codes)
# Out:
# SpearmanrResult(correlation=-0.72715046608532929, pvalue=1.4978126929675338e-64)

# %%
# value and outlook
stats.spearmanr(overall_outlook_cat.cat.codes, overall_value_cat.cat.codes)
# Out:
# SpearmanrResult(correlation=0.82258904334850502, pvalue=6.2515443309034591e-96)

# %%
# pm and outlook
stats.spearmanr(overall_outlook_cat.cat.codes, overall_pm_cat.cat.codes)
# Out:
# SpearmanrResult(correlation=0.71666117797850115, pvalue=6.4922425824804784e-62)

# %%
# try a similar coefficient
stats.kendalltau(overall_threat_cat.cat.codes, overall_outlook_cat.cat.codes, nan_policy='omit')
# Out:
# KendalltauResult(correlation=0.76117673752398907, pvalue=8.4321357080227236e-67)

# %%
# programmatically do all combinations
import itertools

for pair in itertools.combinations([overall_outlook_cat.cat.codes, \
                                    overall_pm_cat.cat.codes, overall_threat_cat.cat.codes,\
                                    overall_value_cat.cat.codes], 2):
    print stats.spearmanr(*pair)
# Out:
# SpearmanrResult(correlation=0.71666117797850115, pvalue=6.4922425824804784e-62)
# SpearmanrResult(correlation=0.81011644618186573, pvalue=7.6216009081694791e-91)
# SpearmanrResult(correlation=0.82258904334850502, pvalue=6.2515443309034591e-96)
# SpearmanrResult(correlation=0.55932266809719888, pvalue=4.5322093693012604e-33)
# SpearmanrResult(correlation=0.5690435610762028, pvalue=2.0449411208785148e-34)
# SpearmanrResult(correlation=0.73120058543218236, pvalue=1.3307379583483082e-65)

# %% [markdown]
# It so appears that significant positive associations in almost all variables, i.e. values, protection and management, threats and final outlook. In other words, the better protection management, the lower threats and less value impact tend to better outlook, which is to be expected

# %% [markdown]
# ### [Inconsistency] investigate the relationship between the potential threat overall and individual potential threats

# %%
pt = potential_threat.copy()
pt['rating_cat'] = pt.rating.astype('category', \
                                 categories=['Very Low Threat', 'Low Threat','High Threat', 'Very High Threat'],\
                                 ordered=True)

# %%
pt.head()
# Out:
#    wdpa_id screenname     status      stage  \
# 0   478640      elena  Completed  Published
# 1    26653      elena  Completed  Published
# 2    26653      elena  Completed  Published
# 3    26653      elena  Completed  Published
# 4    26653      elena  Completed  Published
#
#                                     name_en  \
# 0                      Hierapolis-Pamukkale
# 1  Tsingy de Bemaraha Strict Nature Reserve
# 2  Tsingy de Bemaraha Strict Nature Reserve
# 3  Tsingy de Bemaraha Strict Nature Reserve
# 4  Tsingy de Bemaraha Strict Nature Reserve
#
#                      threat_category               threat_sub_category  \
# 0                  Geological Events             Earthquakes/ Tsunamis
# 1  Climate Change and Severe Weather      Habitat Shifting/ Alteration
# 2  Climate Change and Severe Weather                          Droughts
# 3  Climate Change and Severe Weather              Temperature extremes
# 4       Energy Production and Mining  Oil/ Gas exploration/development
#
#                potential_threat          rating  inside_site  outside_site  \
# 0                   Earthquakes      Low Threat          1.0           0.0
# 1              Habitat shifting  Data Deficient          0.0           0.0
# 2  Changes to rainfall patterns  Data Deficient          0.0           0.0
# 3           Temperature changes  Data Deficient          0.0           0.0
# 4                   Oil and gas  Data Deficient          0.0           0.0
#
#    assessment_cycle  rating_cat
# 0              2014  Low Threat
# 1              2014         NaN
# 2              2014         NaN
# 3              2014         NaN
# 4              2014         NaN

# %%
pt_pt = pt.pivot_table(values='name_en', index='wdpa_id', columns='rating_cat', aggfunc=np.count_nonzero, fill_value=0)

# %%
pt_pt.columns
# Out:
# CategoricalIndex([u'Very Low Threat', u'Low Threat', u'High Threat',
#                   u'Very High Threat'],
#                  categories=[u'Very Low Threat', u'Low Threat', u'High Threat', u'Very High Threat'], ordered=True, name=u'rating_cat', dtype='category')

# %%
pt_pt.index
# Out:
# Int64Index([      191,       197,      2004,      2005,      2006,      2007,
#                  2008,      2010,      2011,      2012,
#             ...
#             555577556, 555577557, 555577558, 555577559, 555577560, 555622040,
#             555622041, 555622043, 555622045, 555622047],
#            dtype='int64', name=u'wdpa_id', length=235)

# %%
# to replace the categorical index to normal index for the columns so that joins/merges can take place
pt_pt.columns = list(pt_pt.columns)

# %%
pt_pt.columns
# Out:
# Index([u'Very Low Threat', u'Low Threat', u'High Threat', u'Very High Threat'], dtype='object')

# %%
pt_pt['wdpa_id'] = pt_pt.index

# %%
a = pt_pt.merge(overall, left_index=True, right_on='wdpa_id')

# %%
a[a.assessment_cycle==2014]
# Out:
#        wdpa_id  Very Low Threat  Low Threat  High Threat  Very High Threat  \
# 177        191                0           2            0                 2
# 117        197                0           2            2                 0
# 202       2004                2           1            0                 0
# 176       2005                0           2            0                 2
# 54        2006                1           2            0                 2
# 190       2007                0           0            0                 0
# 159       2008                0           1            0                 0
# 14        2010                0           0            0                 0
# 106       2011                0           2            8                 0
# 185       2012                0           4            6                 0
# 206       2013                2           5            2                 0
# 76        2015                0           5            6                 3
# 172       2016                0           0            2                 0
# 59        2017                0           0            0                 2
# 227       2018                0           2            2                 0
# 182       2554                0           0            4                 0
# 33        2570                2           2            0                 0
# 198       2571                0           0            0                 2
# 195       2572                0           1            0                 1
# 210       2573                1           0            1                 0
# 50        2574                0           0            4                 2
# 115       2575                0           2            0                 2
# 207       2577                0           2            0                 0
# 65        2578                0           4            0                 0
# 161       2579                0           8            2                 0
# 11        2580                0           0            1                 0
# 17        4322                0           0            0                 0
# 75        4325                0           0            0                 0
# 26        4326                0           2            2                 2
# 36        4327                0           2            0                 0
# ..         ...              ...         ...          ...               ...
# 111     903140                2           0            0                 0
# 101     903141                0           2            2                 0
# 104  555512000                0           2            0                 0
# 21   555512001                0           0            2                 2
# 67   555512002                4           2            0                 0
# 42   555512003                0           2            0                 0
# 92   555512005                0           0            0                 0
# 83   555512006                0           0            0                 0
# 60   555542336                0           4            0                 0
# 47   555542337                0           1            1                 0
# 137  555542338                0           1            0                 0
# 113  555542339                0           2            3                 0
# 178  555547987                2           4            0                 0
# 78   555547988                0           0            4                 0
# 87   555547989                0           1            0                 0
# 183  555547990                0           2            0                 0
# 85   555547991                0           2            0                 0
# 84   555547992                0           1            0                 0
# 228  555555555                0           3            6                 0
# 53   555556045                0           2            0                 0
# 28   555556046                2           0            6                 0
# 144  555556047                2           2            0                 0
# 80   555556048                0           2            2                 0
# 52   555556049                2           0            3                 0
# 129  555577555                0           4            4                 0
# 143  555577556                1           0            0                 0
# 160  555577557                1           4            0                 0
# 175  555577558                0           2            0                 0
# 142  555577559                0           0            2                 2
# 127  555577560                0           0            8                 0
#
#      wdpa_id_x  wdpa_id_y screenname     status       stage       ...         \
# 177        191        191      elena  Completed   Published       ...
# 117        197        197      elena  Completed   Published       ...
# 202       2004       2004      elena  Completed   Published       ...
# 176       2005       2005      elena  Completed   Published       ...
# 54        2006       2006      elena  Completed   Published       ...
# 190       2007       2007      elena  Completed   Published       ...
# 159       2008       2008      elena  Completed   Published       ...
# 14        2010       2010      elena  Completed   Published       ...
# 106       2011       2011      elena  Completed   Published       ...
# 185       2012       2012      elena  Completed   Published       ...
# 206       2013       2013      elena  Completed   Published       ...
# 76        2015       2015      elena  Completed   Published       ...
# 172       2016       2016      elena  Completed   Published       ...
# 59        2017       2017      elena  Completed   Published       ...
# 227       2018       2018      elena  Completed   Published       ...
# 182       2554       2554      elena  Completed   Published       ...
# 33        2570       2570      elena  Completed   Published       ...
# 198       2571       2571      elena  Completed   Published       ...
# 195       2572       2572      elena  Completed   Published       ...
# 210       2573       2573      elena  Completed   Published       ...
# 50        2574       2574      elena  Completed   Published       ...
# 115       2575       2575      elena  Completed   Published       ...
# 207       2577       2577      elena  Completed   Published       ...
# 65        2578       2578      elena  Completed   Published       ...
# 161       2579       2579      elena  Completed   Published       ...
# 11        2580       2580      elena  Completed   Published       ...
# 17        4322       4322      elena  Completed  Translated       ...
# 75        4325       4325      elena  Completed   Published       ...
# 26        4326       4326      elena  Completed   Published       ...
# 36        4327       4327      elena  Completed   Published       ...
# ..         ...        ...        ...        ...         ...       ...
# 111     903140     903140      elena  Completed   Published       ...
# 101     903141     903141      elena  Completed   Published       ...
# 104  555512000  555512000      elena  Completed   Published       ...
# 21   555512001  555512001      elena  Completed   Published       ...
# 67   555512002  555512002      elena  Completed   Published       ...
# 42   555512003  555512003      elena  Completed   Published       ...
# 92   555512005  555512005      elena  Completed   Published       ...
# 83   555512006  555512006      elena  Completed   Published       ...
# 60   555542336  555542336      elena  Completed   Published       ...
# 47   555542337  555542337      elena  Completed   Published       ...
# 137  555542338  555542338      elena  Completed   Published       ...
# 113  555542339  555542339      elena  Completed   Published       ...
# 178  555547987  555547987      elena  Completed   Published       ...
# 78   555547988  555547988      elena  Completed   Published       ...
# 87   555547989  555547989      elena  Completed   Published       ...
# 183  555547990  555547990      elena  Completed   Published       ...
# 85   555547991  555547991      elena  Completed   Published       ...
# 84   555547992  555547992      elena  Completed   Published       ...
# 228  555555555  555555555     tilman  Completed  Assessment       ...
# 53   555556045  555556045      elena  Completed   Published       ...
# 28   555556046  555556046      elena  Completed   Published       ...
# 144  555556047  555556047      elena  Completed   Published       ...
# 80   555556048  555556048      elena  Completed   Published       ...
# 52   555556049  555556049      elena  Completed   Published       ...
# 129  555577555  555577555      elena  Completed   Published       ...
# 143  555577556  555577556      elena  Completed   Published       ...
# 160  555577557  555577557      elena  Completed   Published       ...
# 175  555577558  555577558      elena  Completed   Published       ...
# 142  555577559  555577559      elena  Completed   Published       ...
# 127  555577560  555577560      elena  Completed   Published       ...
#
#        overall_threat    current_threat  potential_threat         prot_mgmt  \
# 177  Very High Threat  Very High Threat  Very High Threat         Effective
# 117        Low Threat        Low Threat        Low Threat      Some Concern
# 202        Low Threat        Low Threat        Low Threat  Highly Effective
# 176        Low Threat        Low Threat       High Threat         Effective
# 54        High Threat       High Threat       High Threat   Serious Concern
# 190       High Threat       High Threat    Data Deficient      Some Concern
# 159        Low Threat        Low Threat    Data Deficient         Effective
# 14         Low Threat       High Threat        Low Threat         Effective
# 106       High Threat        Low Threat       High Threat         Effective
# 185  Very High Threat  Very High Threat       High Threat      Some Concern
# 206        Low Threat        Low Threat       High Threat         Effective
# 76        High Threat       High Threat       High Threat      Some Concern
# 172       High Threat       High Threat        Low Threat         Effective
# 59   Very High Threat       High Threat  Very High Threat      Some Concern
# 227        Low Threat        Low Threat       High Threat         Effective
# 182       High Threat       High Threat       High Threat      Some Concern
# 33         Low Threat        Low Threat        Low Threat         Effective
# 198  Very High Threat       High Threat  Very High Threat         Effective
# 195       High Threat       High Threat       High Threat  Highly Effective
# 210        Low Threat        Low Threat       High Threat         Effective
# 50   Very High Threat  Very High Threat  Very High Threat   Serious Concern
# 115        Low Threat        Low Threat       High Threat         Effective
# 207       High Threat       High Threat        Low Threat         Effective
# 65        High Threat       High Threat        Low Threat      Some Concern
# 161        Low Threat       High Threat        Low Threat  Highly Effective
# 11   Very High Threat  Very High Threat       High Threat   Serious Concern
# 17        High Threat       High Threat    Data Deficient      Some Concern
# 75        High Threat       High Threat    Data Deficient         Effective
# 26        High Threat       High Threat  Very High Threat   Serious Concern
# 36   Very High Threat  Very High Threat        Low Threat      Some Concern
# ..                ...               ...               ...               ...
# 111   Very Low Threat   Very Low Threat   Very Low Threat  Highly Effective
# 101        Low Threat        Low Threat       High Threat      Some Concern
# 104        Low Threat        Low Threat        Low Threat         Effective
# 21         Low Threat        Low Threat       High Threat         Effective
# 67         Low Threat        Low Threat        Low Threat         Effective
# 42    Very Low Threat   Very Low Threat        Low Threat         Effective
# 92         Low Threat        Low Threat    Data Deficient         Effective
# 83        High Threat       High Threat       High Threat         Effective
# 60        High Threat       High Threat        Low Threat         Effective
# 47         Low Threat        Low Threat        Low Threat         Effective
# 137        Low Threat        Low Threat    Data Deficient  Highly Effective
# 113       High Threat       High Threat    Data Deficient         Effective
# 178        Low Threat        Low Threat        Low Threat      Some Concern
# 78        High Threat       High Threat       High Threat      Some Concern
# 87         Low Threat        Low Threat        Low Threat         Effective
# 183       High Threat       High Threat        Low Threat      Some Concern
# 85    Very Low Threat   Very Low Threat        Low Threat         Effective
# 84         Low Threat        Low Threat        Low Threat         Effective
# 228       High Threat       High Threat       High Threat      Some Concern
# 53         Low Threat        Low Threat        Low Threat         Effective
# 28         Low Threat        Low Threat       High Threat         Effective
# 144   Very Low Threat   Very Low Threat               NaN         Effective
# 80         Low Threat        Low Threat        Low Threat         Effective
# 52         Low Threat        Low Threat        Low Threat      Some Concern
# 129        Low Threat        Low Threat       High Threat      Some Concern
# 143   Very Low Threat        Low Threat   Very Low Threat  Highly Effective
# 160        Low Threat        Low Threat        Low Threat         Effective
# 175   Very Low Threat   Very Low Threat        Low Threat         Effective
# 142       High Threat        Low Threat       High Threat      Some Concern
# 127       High Threat       High Threat       High Threat      Some Concern
#
#          wh_value        wh_trend    biodiv_value    biodiv_trend language  \
# 177  High Concern   Deteriorating    High Concern   Deteriorating        1
# 117   Low Concern   Deteriorating     Low Concern   Deteriorating        1
# 202   Low Concern          Stable     Low Concern          Stable        1
# 176          Good          Stable             NaN             NaN        1
# 54   High Concern  Data Deficient             NaN             NaN        1
# 190   Low Concern   Deteriorating  Data Deficient  Data Deficient        1
# 159   Low Concern          Stable             NaN             NaN        1
# 14    Low Concern          Stable             NaN             NaN        1
# 106   Low Concern          Stable             NaN             NaN        1
# 185      Critical   Deteriorating             NaN             NaN        1
# 206   Low Concern          Stable    High Concern  Data Deficient        1
# 76   High Concern   Deteriorating    High Concern  Data Deficient        1
# 172   Low Concern          Stable             NaN             NaN        1
# 59   High Concern  Data Deficient    High Concern  Data Deficient        1
# 227   Low Concern   Deteriorating             NaN             NaN        1
# 182  High Concern   Deteriorating    High Concern   Deteriorating        1
# 33    Low Concern   Deteriorating    High Concern   Deteriorating        1
# 198  High Concern   Deteriorating             NaN             NaN        1
# 195  High Concern          Stable             NaN             NaN        1
# 210          Good          Stable     Low Concern          Stable        1
# 50       Critical          Stable             NaN             NaN        2
# 115   Low Concern          Stable             NaN             NaN        1
# 207   Low Concern          Stable     Low Concern          Stable        1
# 65   High Concern          Stable             NaN             NaN        2
# 161   Low Concern   Deteriorating     Low Concern  Data Deficient        1
# 11       Critical  Data Deficient        Critical  Data Deficient        2
# 17   High Concern       Improving  Data Deficient  Data Deficient        2
# 75           Good          Stable     Low Concern   Deteriorating        1
# 26   High Concern   Deteriorating             NaN             NaN        1
# 36   High Concern  Data Deficient            Good          Stable        1
# ..            ...             ...             ...             ...      ...
# 111          Good          Stable  Data Deficient  Data Deficient        1
# 101   Low Concern          Stable     Low Concern          Stable        1
# 104   Low Concern          Stable             NaN             NaN        1
# 21    Low Concern          Stable             NaN             NaN        1
# 67           Good       Improving            Good       Improving        1
# 42           Good          Stable             NaN             NaN        1
# 92    Low Concern          Stable     Low Concern          Stable        1
# 83    Low Concern          Stable             NaN             NaN        1
# 60    Low Concern  Data Deficient             NaN             NaN        1
# 47    Low Concern  Data Deficient     Low Concern  Data Deficient        1
# 137          Good  Data Deficient            Good  Data Deficient        1
# 113   Low Concern          Stable             NaN             NaN        1
# 178          Good          Stable             NaN             NaN        1
# 78    Low Concern  Data Deficient             NaN             NaN        1
# 87           Good          Stable             NaN             NaN        1
# 183          Good  Data Deficient             NaN             NaN        1
# 85           Good          Stable            Good          Stable        1
# 84    Low Concern          Stable             NaN             NaN        1
# 228  High Concern   Deteriorating    High Concern   Deteriorating        1
# 53           Good          Stable             NaN             NaN        1
# 28    Low Concern          Stable             NaN             NaN        1
# 144          Good          Stable     Low Concern          Stable        1
# 80           Good          Stable             NaN             NaN        1
# 52           Good          Stable     Low Concern          Stable        1
# 129          Good          Stable             NaN             NaN        1
# 143          Good          Stable  Data Deficient  Data Deficient        1
# 160   Low Concern  Data Deficient             NaN             NaN        1
# 175          Good  Data Deficient            Good  Data Deficient        1
# 142  High Concern  Data Deficient     Low Concern  Data Deficient        1
# 127  High Concern   Deteriorating    High Concern   Deteriorating        1
#
#     assessment_cycle
# 177             2014
# 117             2014
# 202             2014
# 176             2014
# 54              2014
# 190             2014
# 159             2014
# 14              2014
# 106             2014
# 185             2014
# 206             2014
# 76              2014
# 172             2014
# 59              2014
# 227             2014
# 182             2014
# 33              2014
# 198             2014
# 195             2014
# 210             2014
# 50              2014
# 115             2014
# 207             2014
# 65              2014
# 161             2014
# 11              2014
# 17              2014
# 75              2014
# 26              2014
# 36              2014
# ..               ...
# 111             2014
# 101             2014
# 104             2014
# 21              2014
# 67              2014
# 42              2014
# 92              2014
# 83              2014
# 60              2014
# 47              2014
# 137             2014
# 113             2014
# 178             2014
# 78              2014
# 87              2014
# 183             2014
# 85              2014
# 84              2014
# 228             2014
# 53              2014
# 28              2014
# 144             2014
# 80              2014
# 52              2014
# 129             2014
# 143             2014
# 160             2014
# 175             2014
# 142             2014
# 127             2014
#
# [229 rows x 22 columns]

# %% [markdown]
# The aggregation of information happens in multiple places. For threats for example, individual potential threats get merged to overall potential threat, then merged to overall threat and then to overall outlook.
#
# The above result of 2014 results shows a somewhat haphazard relationship between the number and the severity of threats identified and the overall potential threat. For example, site of id 191, has 0202 and overall very high threat; while id of 2006 has 1202 and overall high threat. Similarly, 2011, of 0280 -> hight threat, while 2015, 0563 argubly much higher threat scores also high threat. **It so appears that the overall potential threat is not systematically and consistently related to the individual potential threats identified**
#
# Caveats: only potential threats are investigated and no differentiation is made between threats inside or outside.
# Ideas: should all threats be treated the same, i.e. carrying the same weight when considering the overall threat? If so, should distinctions be made?

# %% [markdown]
# ### Attempt a systematic metric for aggregating threats rating
#
# Thinking:
# 1. weighted average considering the following factors: a) number of threats b) for each its threat severity and c) inside or outside
# 2. if all threat categories are considered, i.e. an absolute metric, the resulting values are likely to be in a rather narrow range, as most threat categories are not applicable to the site of interest. Relative metrics may achieve the contract, which may be more desirable.
# 3. for relative metric, i.e. a value that WILL be influenced by the performance of other sites is an undesirable property as comprisons will be meaning less against itself, thus rendering tracking progress unreliable.
# 4. the reduction or generalisation of information IS required to come to one single estimate, however, how can the number of the threats and severity of threats be compared? Does 3 high threats equal to 1 very high threats?
#
# AP: compare between the assessor derived overall threat category and a quanlitative method, probably in the form of normalised sum of threats + threat severity + inside or outside + trend. Do they match?
# AP: similarly do so for pm and values
# AP: aggregation from overall pm values and threats to overall outlook

# %%
pt = potential_threat.copy()
pt['rating_cat'] = pt.rating.astype('category', \
                                 categories=['Very High Threat', 'High Threat', 'Low Threat','Very Low Threat'],\
                                 ordered=True)

# the array.cat.codes would be 0, 1, 2, 3 respectively. Data deficiently would be coded as -1
# which can be later replaced by other values, based on optimistic or pessimistic assumptions

# %%
pt[pt.assessment_cycle==2014].threat_sub_category.value_counts()
# Out:
# Temperature extremes                                                    72
# Mining/ Quarrying                                                       38
# Other                                                                   37
# Tourism/ visitors/ recreation                                           35
# Roads/ Railroads                                                        32
# Habitat Shifting/ Alteration                                            30
# Dams/ Water Management or Use                                           27
# Tourism/ Recreation Areas                                               26
# Oil/ Gas exploration/development                                        25
# Invasive Non-Native/ Alien Species                                      25
# Droughts                                                                19
# Storms/Flooding                                                         17
# Earthquakes/ Tsunamis                                                   16
# Renewable Energy                                                        15
# Water Pollution                                                         13
# Fire/ Fire Suppression                                                  13
# Housing/ Urban Areas                                                    13
# Shipping Lanes                                                          11
# Ocean acidification                                                     11
# Other Activities                                                        10
# Commercial/ Industrial Areas                                             9
# Crops                                                                    9
# Volcanoes                                                                8
# Logging/ Wood Harvesting                                                 8
# Fishing / Harvesting Aquatic Resources                                   8
# Utility / Service Lines                                                  7
# Erosion and Siltation/ Deposition                                        7
# War, Civil Unrest/ Military Exercises                                    6
# Avalanches/ Landslides                                                   6
# Identity/ Social Cohesion/ Changes in local population and community     5
# Changes in traditional ways of life and knowledge systems                4
# Hyper-Abundant Species                                                   4
# Solid Waste                                                              4
# Flight Paths                                                             4
# Crop production                                                          4
# Industrial/ Military Effluents                                           4
# Hunting (commercial/subsistence)                                         4
# Livestock Farming / Grazing                                              2
# Air Pollution                                                            2
# Marine/ Freshwater Aquaculture                                           2
# Forestry/ Wood production                                                1
# Agricultural/ Forestry Effluents                                         1
# Desertification                                                          1
# Modified Genetic Material                                                1
# Poaching                                                                 1
# Name: threat_sub_category, dtype: int64

# %%
# check the number of sites with threat categories
pt[pt.assessment_cycle==2014].wdpa_id.nunique()
# Out:
# 229

# %% [markdown]
# All sites will have at least one threat category

# %%
pt.head()
# Out:
#    wdpa_id screenname     status      stage  \
# 0   478640      elena  Completed  Published
# 1    26653      elena  Completed  Published
# 2    26653      elena  Completed  Published
# 3    26653      elena  Completed  Published
# 4    26653      elena  Completed  Published
#
#                                     name_en  \
# 0                      Hierapolis-Pamukkale
# 1  Tsingy de Bemaraha Strict Nature Reserve
# 2  Tsingy de Bemaraha Strict Nature Reserve
# 3  Tsingy de Bemaraha Strict Nature Reserve
# 4  Tsingy de Bemaraha Strict Nature Reserve
#
#                      threat_category               threat_sub_category  \
# 0                  Geological Events             Earthquakes/ Tsunamis
# 1  Climate Change and Severe Weather      Habitat Shifting/ Alteration
# 2  Climate Change and Severe Weather                          Droughts
# 3  Climate Change and Severe Weather              Temperature extremes
# 4       Energy Production and Mining  Oil/ Gas exploration/development
#
#                potential_threat          rating  inside_site  outside_site  \
# 0                   Earthquakes      Low Threat          1.0           0.0
# 1              Habitat shifting  Data Deficient          0.0           0.0
# 2  Changes to rainfall patterns  Data Deficient          0.0           0.0
# 3           Temperature changes  Data Deficient          0.0           0.0
# 4                   Oil and gas  Data Deficient          0.0           0.0
#
#    assessment_cycle  rating_cat
# 0              2014  Low Threat
# 1              2014         NaN
# 2              2014         NaN
# 3              2014         NaN
# 4              2014         NaN

# %%
# choose different assumptions
pt.rating_cat.fillna('Low Threat')
# Out:
# 0             Low Threat
# 1             Low Threat
# 2             Low Threat
# 3             Low Threat
# 4             Low Threat
# 5            High Threat
# 6             Low Threat
# 7             Low Threat
# 8       Very High Threat
# 9            High Threat
# 10            Low Threat
# 11            Low Threat
# 12            Low Threat
# 13            Low Threat
# 14            Low Threat
# 15            Low Threat
# 16            Low Threat
# 17            Low Threat
# 18            Low Threat
# 19            Low Threat
# 20            Low Threat
# 21            Low Threat
# 22            Low Threat
# 23           High Threat
# 24       Very Low Threat
# 25            Low Threat
# 26            Low Threat
# 27      Very High Threat
# 28           High Threat
# 29            Low Threat
#               ...
# 995     Very High Threat
# 996      Very Low Threat
# 997           Low Threat
# 998           Low Threat
# 999           Low Threat
# 1000          Low Threat
# 1001     Very Low Threat
# 1002     Very Low Threat
# 1003          Low Threat
# 1004          Low Threat
# 1005          Low Threat
# 1006     Very Low Threat
# 1007          Low Threat
# 1008          Low Threat
# 1009          Low Threat
# 1010          Low Threat
# 1011          Low Threat
# 1012          Low Threat
# 1013          Low Threat
# 1014          Low Threat
# 1015          Low Threat
# 1016          Low Threat
# 1017          Low Threat
# 1018          Low Threat
# 1019          Low Threat
# 1020          Low Threat
# 1021          Low Threat
# 1022          Low Threat
# 1023          Low Threat
# 1024          Low Threat
# Name: rating_cat, Length: 1025, dtype: category
# Categories (4, object): [Very High Threat < High Threat < Low Threat < Very Low Threat]

# %%
test191 = pt[(pt.wdpa_id==191) & (pt.assessment_cycle==2014)]

# %%
test191
# Out:
#      wdpa_id screenname     status      stage            name_en  \
# 449      191      elena  Completed  Published  Galápagos Islands
# 450      191      elena  Completed  Published  Galápagos Islands
#
#                                       threat_category  \
# 449                                             Other
# 450  Invasive and Other Problematic Species and Genes
#
#                     threat_sub_category  \
# 449                               Other
# 450  Invasive Non-Native/ Alien Species
#
#                                       potential_threat            rating  \
# 449                                     Sea level rise        Low Threat
# 450  New introductions and re-introduction of invas...  Very High Threat
#
#      inside_site  outside_site  assessment_cycle        rating_cat
# 449          1.0           0.0              2014        Low Threat
# 450          1.0           0.0              2014  Very High Threat

# %%
test191.index.size
# Out:
# 2

# %%
W_INSIDE = 0.8
W_OUTSIDE = 1 - W_INSIDE

# %% [markdown]
# ## Detailed pivot table counting

# %% [markdown]
# Use potential threat as an example to illustrate pivot table by multiple indices.

# %%
# threat ratings for ordering df
threat_ratings = ['Data Deficient', u'Very Low Threat', u'Low Threat', 'High Threat', u'Very High Threat']

# %%
# use a dict to unpack arguments, easier to see
# fill_value=0 removes NaN values
threat_pivot_settings = dict(values='wdpa_id', index=['threat_category', 'threat_sub_category'],
                             columns='rating', aggfunc=np.count_nonzero, fill_value=0)

# %%
# delta: change in threat
a = potential_threat[potential_threat.assessment_cycle==2014].pivot_table(**threat_pivot_settings)
b = potential_threat[potential_threat.assessment_cycle==2017].pivot_table(**threat_pivot_settings)
c = pd.merge(a, b, how='inner', left_index=True, right_index=True)

for rating in threat_ratings:
    # 2017 minus 2014
    c[rating + '_delta'] = c[rating + '_y'] - c[rating + '_x']
    
    # drop x, y fields, in place
    c.drop(rating + '_x', axis=1, inplace=True)
    c.drop(rating + '_y', axis=1, inplace=True)

# %%
# delta, change 2014 to 2017
c
# Out:
# rating                                                                                               Data Deficient_delta  \
# threat_category                                  threat_sub_category
# Agriculture and Aquaculture                      Crop production                                                        0
#                                                  Crops                                                                  0
#                                                  Forestry/ Wood production                                              0
#                                                  Livestock Farming / Grazing                                            0
#                                                  Marine/ Freshwater Aquaculture                                         0
# Biological Resource Use                          Fishing / Harvesting Aquatic Resources                                -1
#                                                  Hunting (commercial/subsistence)                                       0
#                                                  Logging/ Wood Harvesting                                               0
#                                                  Poaching                                                               0
# Climate Change and Severe Weather                Desertification                                                        0
#                                                  Droughts                                                              -2
#                                                  Habitat Shifting/ Alteration                                          -4
#                                                  Ocean acidification                                                    1
#                                                  Storms/Flooding                                                       -3
#                                                  Temperature extremes                                                  -7
# Energy Production and Mining                     Mining/ Quarrying                                                     -2
#                                                  Oil/ Gas exploration/development                                      -2
#                                                  Renewable Energy                                                       1
# Geological Events                                Avalanches/ Landslides                                                -2
#                                                  Earthquakes/ Tsunamis                                                  0
#                                                  Erosion and Siltation/ Deposition                                      0
#                                                  Volcanoes                                                             -1
# Human Intrusions and Disturbance                 Other Activities                                                      -1
#                                                  Tourism/ visitors/ recreation                                         -2
#                                                  War, Civil Unrest/ Military Exercises                                  0
# Invasive and Other Problematic Species and Genes Hyper-Abundant Species                                                 0
#                                                  Invasive Non-Native/ Alien Species                                    -1
#                                                  Modified Genetic Material                                              0
# Natural System Modifications                     Dams/ Water Management or Use                                         -2
#                                                  Fire/ Fire Suppression                                                -1
# Other                                            Other                                                                 -3
# Pollution                                        Air Pollution                                                          1
#                                                  Industrial/ Military Effluents                                         0
#                                                  Solid Waste                                                            0
#                                                  Water Pollution                                                        0
# Residential and Commercial Development           Commercial/ Industrial Areas                                          -1
#                                                  Housing/ Urban Areas                                                   0
#                                                  Tourism/ Recreation Areas                                              0
# Social/ Cultural Changes                         Changes in traditional ways of life and knowled...                     0
#                                                  Identity/ Social Cohesion/ Changes in local pop...                    -1
# Transportation and Service Corridors             Flight Paths                                                           0
#                                                  Roads/ Railroads                                                      -4
#                                                  Shipping Lanes                                                         0
#                                                  Utility / Service Lines                                                0
#
# rating                                                                                               Very Low Threat_delta  \
# threat_category                                  threat_sub_category
# Agriculture and Aquaculture                      Crop production                                                         0
#                                                  Crops                                                                   0
#                                                  Forestry/ Wood production                                               0
#                                                  Livestock Farming / Grazing                                             1
#                                                  Marine/ Freshwater Aquaculture                                          0
# Biological Resource Use                          Fishing / Harvesting Aquatic Resources                                  0
#                                                  Hunting (commercial/subsistence)                                        0
#                                                  Logging/ Wood Harvesting                                                0
#                                                  Poaching                                                               -1
# Climate Change and Severe Weather                Desertification                                                         0
#                                                  Droughts                                                                0
#                                                  Habitat Shifting/ Alteration                                            1
#                                                  Ocean acidification                                                     0
#                                                  Storms/Flooding                                                         0
#                                                  Temperature extremes                                                   -2
# Energy Production and Mining                     Mining/ Quarrying                                                      -1
#                                                  Oil/ Gas exploration/development                                       -1
#                                                  Renewable Energy                                                        0
# Geological Events                                Avalanches/ Landslides                                                 -3
#                                                  Earthquakes/ Tsunamis                                                  -2
#                                                  Erosion and Siltation/ Deposition                                      -2
#                                                  Volcanoes                                                              -1
# Human Intrusions and Disturbance                 Other Activities                                                        0
#                                                  Tourism/ visitors/ recreation                                          -2
#                                                  War, Civil Unrest/ Military Exercises                                  -2
# Invasive and Other Problematic Species and Genes Hyper-Abundant Species                                                  0
#                                                  Invasive Non-Native/ Alien Species                                      0
#                                                  Modified Genetic Material                                               0
# Natural System Modifications                     Dams/ Water Management or Use                                          -2
#                                                  Fire/ Fire Suppression                                                  0
# Other                                            Other                                                                  -1
# Pollution                                        Air Pollution                                                           0
#                                                  Industrial/ Military Effluents                                         -1
#                                                  Solid Waste                                                            -1
#                                                  Water Pollution                                                         1
# Residential and Commercial Development           Commercial/ Industrial Areas                                            0
#                                                  Housing/ Urban Areas                                                    0
#                                                  Tourism/ Recreation Areas                                              -1
# Social/ Cultural Changes                         Changes in traditional ways of life and knowled...                      0
#                                                  Identity/ Social Cohesion/ Changes in local pop...                      0
# Transportation and Service Corridors             Flight Paths                                                           -1
#                                                  Roads/ Railroads                                                       -2
#                                                  Shipping Lanes                                                         -1
#                                                  Utility / Service Lines                                                 0
#
# rating                                                                                               Low Threat_delta  \
# threat_category                                  threat_sub_category
# Agriculture and Aquaculture                      Crop production                                                   -1
#                                                  Crops                                                              2
#                                                  Forestry/ Wood production                                          0
#                                                  Livestock Farming / Grazing                                        0
#                                                  Marine/ Freshwater Aquaculture                                     0
# Biological Resource Use                          Fishing / Harvesting Aquatic Resources                             0
#                                                  Hunting (commercial/subsistence)                                  -2
#                                                  Logging/ Wood Harvesting                                          -4
#                                                  Poaching                                                           0
# Climate Change and Severe Weather                Desertification                                                    0
#                                                  Droughts                                                           0
#                                                  Habitat Shifting/ Alteration                                      -1
#                                                  Ocean acidification                                                0
#                                                  Storms/Flooding                                                   -2
#                                                  Temperature extremes                                              -6
# Energy Production and Mining                     Mining/ Quarrying                                                 -4
#                                                  Oil/ Gas exploration/development                                  -2
#                                                  Renewable Energy                                                  -1
# Geological Events                                Avalanches/ Landslides                                             0
#                                                  Earthquakes/ Tsunamis                                             -4
#                                                  Erosion and Siltation/ Deposition                                 -3
#                                                  Volcanoes                                                          0
# Human Intrusions and Disturbance                 Other Activities                                                   1
#                                                  Tourism/ visitors/ recreation                                    -10
#                                                  War, Civil Unrest/ Military Exercises                              0
# Invasive and Other Problematic Species and Genes Hyper-Abundant Species                                             0
#                                                  Invasive Non-Native/ Alien Species                                -2
#                                                  Modified Genetic Material                                          0
# Natural System Modifications                     Dams/ Water Management or Use                                     -2
#                                                  Fire/ Fire Suppression                                            -2
# Other                                            Other                                                             -6
# Pollution                                        Air Pollution                                                     -1
#                                                  Industrial/ Military Effluents                                    -1
#                                                  Solid Waste                                                       -1
#                                                  Water Pollution                                                   -3
# Residential and Commercial Development           Commercial/ Industrial Areas                                       1
#                                                  Housing/ Urban Areas                                              -3
#                                                  Tourism/ Recreation Areas                                         -6
# Social/ Cultural Changes                         Changes in traditional ways of life and knowled...                 0
#                                                  Identity/ Social Cohesion/ Changes in local pop...                -1
# Transportation and Service Corridors             Flight Paths                                                       0
#                                                  Roads/ Railroads                                                   0
#                                                  Shipping Lanes                                                     0
#                                                  Utility / Service Lines                                            1
#
# rating                                                                                               High Threat_delta  \
# threat_category                                  threat_sub_category
# Agriculture and Aquaculture                      Crop production                                                    -1
#                                                  Crops                                                              -2
#                                                  Forestry/ Wood production                                           0
#                                                  Livestock Farming / Grazing                                         0
#                                                  Marine/ Freshwater Aquaculture                                      1
# Biological Resource Use                          Fishing / Harvesting Aquatic Resources                             -1
#                                                  Hunting (commercial/subsistence)                                    0
#                                                  Logging/ Wood Harvesting                                           -1
#                                                  Poaching                                                            1
# Climate Change and Severe Weather                Desertification                                                     0
#                                                  Droughts                                                           -1
#                                                  Habitat Shifting/ Alteration                                       -7
#                                                  Ocean acidification                                                -2
#                                                  Storms/Flooding                                                     0
#                                                  Temperature extremes                                               -9
# Energy Production and Mining                     Mining/ Quarrying                                                  -4
#                                                  Oil/ Gas exploration/development                                   -1
#                                                  Renewable Energy                                                   -3
# Geological Events                                Avalanches/ Landslides                                              0
#                                                  Earthquakes/ Tsunamis                                              -2
#                                                  Erosion and Siltation/ Deposition                                   0
#                                                  Volcanoes                                                          -1
# Human Intrusions and Disturbance                 Other Activities                                                   -3
#                                                  Tourism/ visitors/ recreation                                      -1
#                                                  War, Civil Unrest/ Military Exercises                              -1
# Invasive and Other Problematic Species and Genes Hyper-Abundant Species                                              0
#                                                  Invasive Non-Native/ Alien Species                                 -3
#                                                  Modified Genetic Material                                           0
# Natural System Modifications                     Dams/ Water Management or Use                                       1
#                                                  Fire/ Fire Suppression                                             -1
# Other                                            Other                                                              -4
# Pollution                                        Air Pollution                                                       0
#                                                  Industrial/ Military Effluents                                      0
#                                                  Solid Waste                                                         0
#                                                  Water Pollution                                                    -1
# Residential and Commercial Development           Commercial/ Industrial Areas                                        0
#                                                  Housing/ Urban Areas                                                1
#                                                  Tourism/ Recreation Areas                                          -3
# Social/ Cultural Changes                         Changes in traditional ways of life and knowled...                  0
#                                                  Identity/ Social Cohesion/ Changes in local pop...                 -1
# Transportation and Service Corridors             Flight Paths                                                        0
#                                                  Roads/ Railroads                                                    0
#                                                  Shipping Lanes                                                     -3
#                                                  Utility / Service Lines                                            -1
#
# rating                                                                                               Very High Threat_delta
# threat_category                                  threat_sub_category
# Agriculture and Aquaculture                      Crop production                                                          0
#                                                  Crops                                                                    0
#                                                  Forestry/ Wood production                                                0
#                                                  Livestock Farming / Grazing                                              0
#                                                  Marine/ Freshwater Aquaculture                                           0
# Biological Resource Use                          Fishing / Harvesting Aquatic Resources                                   0
#                                                  Hunting (commercial/subsistence)                                         0
#                                                  Logging/ Wood Harvesting                                                 0
#                                                  Poaching                                                                 0
# Climate Change and Severe Weather                Desertification                                                          0
#                                                  Droughts                                                                 0
#                                                  Habitat Shifting/ Alteration                                             0
#                                                  Ocean acidification                                                      0
#                                                  Storms/Flooding                                                          0
#                                                  Temperature extremes                                                    -4
# Energy Production and Mining                     Mining/ Quarrying                                                       -1
#                                                  Oil/ Gas exploration/development                                        -3
#                                                  Renewable Energy                                                         0
# Geological Events                                Avalanches/ Landslides                                                   0
#                                                  Earthquakes/ Tsunamis                                                    0
#                                                  Erosion and Siltation/ Deposition                                        0
#                                                  Volcanoes                                                                0
# Human Intrusions and Disturbance                 Other Activities                                                         0
#                                                  Tourism/ visitors/ recreation                                            0
#                                                  War, Civil Unrest/ Military Exercises                                    0
# Invasive and Other Problematic Species and Genes Hyper-Abundant Species                                                   0
#                                                  Invasive Non-Native/ Alien Species                                      -1
#                                                  Modified Genetic Material                                                0
# Natural System Modifications                     Dams/ Water Management or Use                                           -1
#                                                  Fire/ Fire Suppression                                                   0
# Other                                            Other                                                                   -1
# Pollution                                        Air Pollution                                                            1
#                                                  Industrial/ Military Effluents                                           1
#                                                  Solid Waste                                                              0
#                                                  Water Pollution                                                          1
# Residential and Commercial Development           Commercial/ Industrial Areas                                            -2
#                                                  Housing/ Urban Areas                                                     0
#                                                  Tourism/ Recreation Areas                                                0
# Social/ Cultural Changes                         Changes in traditional ways of life and knowled...                       0
#                                                  Identity/ Social Cohesion/ Changes in local pop...                       0
# Transportation and Service Corridors             Flight Paths                                                             0
#                                                  Roads/ Railroads                                                        -1
#                                                  Shipping Lanes                                                           0
#                                                  Utility / Service Lines                                                  0

# %% [markdown]
# Generic heat map for visualisation. It presents a better method of spotting hotspot and coldspot

# %%
def heat_map(df, title, colorscale=[[0, '#fffff2'], [0.5, 'fd8d3c'], [1, '#bd0026']]):
    import plotly.graph_objs as go

    # index
    if type(df.index) == pd.core.indexes.multi.MultiIndex:
        y = [': '.join(each) for each in df.index.tolist()]
    elif type(df.index) == pd.core.indexes.base.Index:
        y = df.index.tolist()
    else:
        raise Exception('index type error {}'.format(type(df.index)))
    
    data = [go.Heatmap(z=df.values.tolist(), x=df.columns.tolist(),
                       y=y,
                       colorscale=colorscale)]

    layout = go.Layout(
    #     width=600,
        height=800,
        title=title,
        yaxis=dict(
            tickfont=dict(
                size=8
            )
        ))

    fig = go.Figure(data=data, layout=layout)
    # plot offline
#     plotly.offline.plot(fig)
    return py.iplot(fig, filename=title+'_heatmap')

# %%
heat_map(c, 'Potential threat change 2017 minus 2014', 'Blued')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~yichuans/21.embed" height="800px" width="100%"></iframe>

# %%
a = a[threat_ratings]
heat_map(a, 'Potential threats sub category 2014')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~yichuans/17.embed" height="800px" width="100%"></iframe>

# %%
b = b[threat_ratings]
heat_map(b, 'Potential threat sub category 2017')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~yichuans/19.embed" height="800px" width="100%"></iframe>

# %% [markdown]
# Testing simple index

# %%
a = current_threat[current_threat.assessment_cycle==2014]

# %%
# this setting looks only at threat_catogry as a whole
threat_pivot_settings2 = dict(values='wdpa_id', index=['threat_category'],
                             columns='rating', aggfunc=np.count_nonzero, fill_value=0)

# %%
# multiIndex
b = a.pivot_table(**threat_pivot_settings)

# %%
heat_map(b[threat_ratings], 'Current threat sub category 2014')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~yichuans/25.embed" height="800px" width="100%"></iframe>

# %%
# Index
c = a.pivot_table(**threat_pivot_settings2)

# %%
heat_map(c[threat_ratings], 'Current threat 2014')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~yichuans/23.embed" height="800px" width="100%"></iframe>

# %%
del a, b, c

# %% [markdown]
# ## EXPERIMENT - plotly graphing

# %%
df = summary_statistics(overall[CYCLE_2017_OVERALL], 'outlook')

# %%
df.columns.tolist()
# Out:
# [u'Critical', u'Good', u'Good with some concerns', u'Significant Concern']

# %%
data = ff.create_table(df)

py.iplot(data, filename='basic_bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~yichuans/1.embed" height="110px" width="100%"></iframe>

# %%
def py_overview(year):
    if year == 2014:
        CYCLE = CYCLE_2014_OVERALL
    elif year == 2017:
        CYCLE = CYCLE_2017_OVERALL
    else:
        raise Exception('year has to be either 2014 or 2017')
    a = summary_statistics(overall[CYCLE], 'outlook')
    b = a.transpose()
    c = b.reset_index()
    c.columns = ['outlook', 'rating']
    
    return c

# %%
data = zip([py_overview(2014), py_overview(2017)], ['2014 outlook', '2017 outlook'])

# %%
data = [Bar(x=result[0].outlook, y=result[0].rating, name=result[1]) for result in data]

# %%
py.iplot(data, filename='test')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~yichuans/3.embed" height="525px" width="100%"></iframe>
